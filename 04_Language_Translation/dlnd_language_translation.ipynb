# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # Use <UNK> if a word is not contained in source_vocab_to_int or target_vocab_to_int.
    source_unk_id = source_vocab_to_int['<UNK>']
    source_id_text = [[source_vocab_to_int.get(w, source_unk_id) for w in s.split(' ')] for s in source_text.split('\n')]
       
    target_unk_id = target_vocab_to_int['<UNK>']
    target_id_text = []
    for s in target_text.split('\n'):
        ids = [target_vocab_to_int.get(w, target_unk_id) for w in s.split(' ')]
        ids.append(target_vocab_to_int['<EOS>'])
        target_id_text.append(ids)
    
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# /Users/d065035/anaconda3/envs/tensorflow_1.1/lib/python3.6/site-packages/ipykernel/__main__.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    input_data = tf.placeholder(tf.int32, [None, None], name="input")
    targets = tf.placeholder(tf.int32, [None, None], name="targets")
    learning_rate = tf.placeholder(tf.float32, name="learning_rate")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    target_sequence_length = tf.placeholder(tf.int32, (None,), name="target_sequence_length")
    max_target_len = tf.reduce_max(target_sequence_length, name="max_target_len")
    source_sequence_length = tf.placeholder(tf.int32, (None,), name="source_sequence_length")
    
    return input_data, targets, learning_rate, keep_prob, target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    sliced = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    go = tf.fill([batch_size, 1], target_vocab_to_int['<GO>'])
    return tf.concat([go, sliced], 1)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    
    # Shape: [batch size, sequence length, embedding size]
    embedded_input = tf.contrib.layers.embed_sequence(ids=rnn_inputs,
                                                      vocab_size=source_vocab_size,
                                                      embed_dim=encoding_embedding_size)
    
    def lstm_cell(num_units):
        cell = tf.contrib.rnn.LSTMCell(num_units=num_units,
                                       initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return tf.contrib.rnn.DropoutWrapper(cell=cell, input_keep_prob=keep_prob)
    
    lstm_cells = [lstm_cell(rnn_size) for _ in range(num_layers)]
    rnn_cells = tf.contrib.rnn.MultiRNNCell(cells=lstm_cells)
    
    output, state = tf.nn.dynamic_rnn(cell=rnn_cells,
                                      inputs=embedded_input,
                                      sequence_length=source_sequence_length,
                                      dtype=tf.float32)
    return output, state


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_target_sequence_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    
    # According to the review, dropout should be used here. However, I'm still not sure
    # how to apply it. The passed in RNN cells ("dec_cell") already have dropout applied
    # to them. See the decoding_layer() function. So that should be enough, right?
    # Note, dropout should ONLY be used in the training part, not in the inference part.
    
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input, 
                                                        sequence_length=target_sequence_length)
    
    training_decoder = tf.contrib.seq2seq.BasicDecoder(cell=dec_cell,
                                                       helper=training_helper,
                                                       initial_state=encoder_state,
                                                       output_layer=output_layer)
    
    training_logits, _ = tf.contrib.seq2seq.dynamic_decode(decoder=training_decoder,
                                                           impute_finished=True,
                                                           maximum_iterations=max_target_sequence_length)
    
    return training_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    
    # According to the review, dropout should NOT be used here. If we added it to the
    # inference part, we would lose some connections. I'm already taking care of this
    # in the decoding_layer() function which adds dropout to the RNN cells.
    
    start_token=tf.constant([start_of_sequence_id], dtype=tf.int32)
    start_tokens=tf.tile(start_token, [batch_size], name="start_tokens")
    
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(embedding=dec_embeddings,
                                                                start_tokens=start_tokens,
                                                                end_token=end_of_sequence_id)
    
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(cell=dec_cell,
                                                        helper=inference_helper,
                                                        initial_state=encoder_state,
                                                        output_layer=output_layer)
    
    inference_logits, _ = tf.contrib.seq2seq.dynamic_decode(decoder=inference_decoder,
                                                            impute_finished=True,
                                                            maximum_iterations=max_target_sequence_length)
    
    return inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """ 
    
    # Embed the target sequences.
    # ---------------------------
    # Shape: [vocab_size, embedding_size]
    embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    # Shape: [batch_size, sequence_length, embedding_size]
    embedding_lookup = tf.nn.embedding_lookup(params=embeddings, ids=dec_input)
        
    # Construct the decoder LSTM cells.
    # ---------------------------------
    # According to the review, dropout should only be used in the training part,
    # but not in the inference part. I'm adding "use_drop" to control this. However,
    # see the problem description below.
    def lstm_cell(num_units, use_dropout=True):
        cell = tf.contrib.rnn.LSTMCell(num_units=num_units,
                                       initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        if use_dropout:
            cell = tf.contrib.rnn.DropoutWrapper(cell=cell, input_keep_prob=keep_prob)

        return cell
    
    # Unfortunately, the following doesn't work. I'm trying to create one MultiRNNCell
    # for training and one for inference where the former uses dropout and the latter doesn't.
    # I'm getting the following error:
    # 
    # Attempt to have a second RNNCell use the weights of a variable scope that already has
    # weights: 'decode/decoder/multi_rnn_cell/cell_0/lstm_cell'; and the cell was not constructed
    # as LSTMCell(..., reuse=True).  To share the weights of an RNNCell, simply reuse it in your
    # second calculation, or create a new one with the argument reuse=True.
    #
    # training_lstm_cells = [lstm_cell(rnn_size) for layer in range(num_layers)]
    # training_rnn_cells = tf.contrib.rnn.MultiRNNCell(cells=training_lstm_cells)
    # inference_lstm_cells = [lstm_cell(rnn_size, use_dropout=False) for _ in range(num_layers)]
    # inference_rnn_cells = tf.contrib.rnn.MultiRNNCell(cells=inference_lstm_cells)
    
    lstm_cells = [lstm_cell(rnn_size) for _ in range(num_layers)]
    rnn_cells = tf.contrib.rnn.MultiRNNCell(cells=lstm_cells)
    
    # Create an output layer.
    # -----------------------
    output_layer = Dense(units=target_vocab_size,
                         kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1))
    
    # Get the training logits.
    # ------------------------
    with tf.variable_scope("decode"):
        training_logits = decoding_layer_train(encoder_state=encoder_state,
                                              dec_cell=rnn_cells,
                                              dec_embed_input=embedding_lookup,
                                              target_sequence_length=target_sequence_length,
                                              max_target_sequence_length=max_target_sequence_length,
                                              output_layer=output_layer,
                                              keep_prob=keep_prob)
    
    # Get the inference logits.
    # -------------------------
    with tf.variable_scope("decode", reuse=True):
        inference_logits = decoding_layer_infer(encoder_state=encoder_state,
                                                dec_cell=rnn_cells,
                                                dec_embeddings=embeddings,
                                                start_of_sequence_id=target_vocab_to_int["<GO>"],
                                                end_of_sequence_id=target_vocab_to_int["<EOS>"],
                                                max_target_sequence_length=max_target_sequence_length,
                                                vocab_size=target_vocab_size,
                                                output_layer=output_layer,
                                                batch_size=batch_size,
                                                keep_prob=keep_prob)

    
    return training_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network.
    :param input_data: Input placeholder.
    :param target_data: Target placeholder.
    :param keep_prob: Dropout keep probability placeholder.
    :param batch_size: Batch size.
    :param source_sequence_length: Sequence lengths of source sequences in the batch.
    :param target_sequence_length: Sequence lengths of target sequences in the batch.
    :param source_vocab_size: Source vocabulary size.
    :param target_vocab_size: Target vocabulary size.
    :param enc_embedding_size: Decoder embedding size.
    :param dec_embedding_size: Encoder embedding size.
    :param rnn_size: RNN size.
    :param num_layers: Number of layers.
    :param target_vocab_to_int: Dictionary to go from target words to IDs.
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    print("input_data: {}".format(input_data))  # Shape: [batch_size, sequence_length]
    print("target_data: {}".format(input_data))  # Shape: [batch_size, sequence_length]
    print("keep_prob: {}".format(keep_prob))
    print("batch_size: {}".format(batch_size))    
    print("source_sequence_length: {}".format(source_sequence_length))
    print("target_sequence_length: {}".format(target_sequence_length))
    print("source_vocab_size: {}".format(source_vocab_size))
    print("target_vocab_size: {}".format(target_vocab_size))
    print("enc_embedding_size: {}".format(enc_embedding_size)) 
    print("dec_embedding_size: {}".format(dec_embedding_size)) 
    print("rnn_size: {}".format(rnn_size))
    print("num_layers: {}".format(num_layers))
    
    # Encode the input.
    encoder_output, encoder_state = encoding_layer(rnn_inputs=input_data,
                                                   rnn_size=rnn_size,
                                                   num_layers=num_layers,
                                                   keep_prob=keep_prob,
                                                   source_sequence_length=source_sequence_length,
                                                   source_vocab_size=source_vocab_size,
                                                   encoding_embedding_size=enc_embedding_size)
    
    # Process the target data.    
    decoder_input = process_decoder_input(target_data=target_data,
                                          target_vocab_to_int=target_vocab_to_int,
                                          batch_size=batch_size)
        
    # Decode the encoded input.                    
    training_logits, inference_logits = decoding_layer(dec_input=decoder_input,
                                                       encoder_state=encoder_state,
                                                       target_sequence_length=target_sequence_length,
                                                       max_target_sequence_length=max_target_sentence_length,
                                                       rnn_size=rnn_size,
                                                       num_layers=num_layers,
                                                       target_vocab_to_int=target_vocab_to_int,
                                                       target_vocab_size=target_vocab_size,
                                                       batch_size=batch_size,
                                                       keep_prob=keep_prob,
                                                       decoding_embedding_size=dec_embedding_size)    
    
    return training_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# input_data: Tensor("Placeholder_6:0", shape=(64, 22), dtype=int32)
# target_data: Tensor("Placeholder_6:0", shape=(64, 22), dtype=int32)
# keep_prob: Tensor("Placeholder_8:0", dtype=float32)
# batch_size: 64
# source_sequence_length: Tensor("source_sequence_length:0", shape=(?,), dtype=int32)
# target_sequence_length: Tensor("target_sequence_length:0", shape=(?,), dtype=int32)
# source_vocab_size: 300
# target_vocab_size: 300
# enc_embedding_size: 100
# dec_embedding_size: 100
# rnn_size: 512
# num_layers: 3
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of epochs.
# Based on the review, I lowered the number of epochs from 30 to 15. This should
# already get me above 90% validation accuracy.
epochs = 15

# Batch size.
batch_size = 128

# RNN size, i.e. the number of hidden units in the LSTM cells.
rnn_size = 64

# Number of LSTM layers.
num_layers = 2

# Embedding sizes.
# I read somewhere that the embedding size should be bigger than the RNN size.
# Based on the review, I increased the embedding size from 128 to 200.
encoding_embedding_size = 200
decoding_embedding_size = 200

# Learning rate.
learning_rate = 0.001

# Dropout keep probability.
keep_probability = 0.6

# How many steps between each debug statement?
display_step = 51

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)
# Out:
# input_data: Tensor("ReverseV2:0", shape=(?, ?), dtype=int32)
# target_data: Tensor("ReverseV2:0", shape=(?, ?), dtype=int32)
# keep_prob: Tensor("keep_prob:0", dtype=float32)
# batch_size: 128
# source_sequence_length: Tensor("source_sequence_length:0", shape=(?,), dtype=int32)
# target_sequence_length: Tensor("target_sequence_length:0", shape=(?,), dtype=int32)
# source_vocab_size: 231
# target_vocab_size: 358
# enc_embedding_size: 200
# dec_embedding_size: 200
# rnn_size: 64
# num_layers: 2

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
# I'm addinga few things to plot the loss and test/validation accuracies.
# See the START and END delimiters.

# ----- START ----- #
# %matplotlib inline

import matplotlib.pyplot as plt

batches = []
losses = []
train_accs = []
valid_accs = []
# ----- END ----- #

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:

                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                # ----- START ----- #
                previous_batch = batches[-1] if batches else 0
                batches.append(display_step + previous_batch)
                losses.append(loss)
                train_accs.append(train_acc)
                valid_accs.append(valid_acc)
                # ----- END ----- #

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)

    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   51/1077 - Train Accuracy: 0.2953, Validation Accuracy: 0.3366, Loss: 3.2510
# Epoch   0 Batch  102/1077 - Train Accuracy: 0.3496, Validation Accuracy: 0.3878, Loss: 2.9164
# Epoch   0 Batch  153/1077 - Train Accuracy: 0.3535, Validation Accuracy: 0.4215, Loss: 2.7935
# Epoch   0 Batch  204/1077 - Train Accuracy: 0.3895, Validation Accuracy: 0.4474, Loss: 2.5582
# Epoch   0 Batch  255/1077 - Train Accuracy: 0.4223, Validation Accuracy: 0.4741, Loss: 2.3953
# Epoch   0 Batch  306/1077 - Train Accuracy: 0.4754, Validation Accuracy: 0.5099, Loss: 2.1374
# Epoch   0 Batch  357/1077 - Train Accuracy: 0.5104, Validation Accuracy: 0.5121, Loss: 1.9189
# Epoch   0 Batch  408/1077 - Train Accuracy: 0.4695, Validation Accuracy: 0.5138, Loss: 1.8993
# Epoch   0 Batch  459/1077 - Train Accuracy: 0.4866, Validation Accuracy: 0.5124, Loss: 1.6641
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.4820, Validation Accuracy: 0.5053, Loss: 1.5333
# Epoch   0 Batch  561/1077 - Train Accuracy: 0.4918, Validation Accuracy: 0.5114, Loss: 1.3446
# Epoch   0 Batch  612/1077 - Train Accuracy: 0.5104, Validation Accuracy: 0.5362, Loss: 1.2170
# Epoch   0 Batch  663/1077 - Train Accuracy: 0.4566, Validation Accuracy: 0.5192, Loss: 1.1895
# Epoch   0 Batch  714/1077 - Train Accuracy: 0.4792, Validation Accuracy: 0.5298, Loss: 1.1335
# Epoch   0 Batch  765/1077 - Train Accuracy: 0.5164, Validation Accuracy: 0.5305, Loss: 1.0241
# Epoch   0 Batch  816/1077 - Train Accuracy: 0.4926, Validation Accuracy: 0.5185, Loss: 1.0535
# Epoch   0 Batch  867/1077 - Train Accuracy: 0.4793, Validation Accuracy: 0.5401, Loss: 1.0247
# Epoch   0 Batch  918/1077 - Train Accuracy: 0.5391, Validation Accuracy: 0.5412, Loss: 0.8802
# Epoch   0 Batch  969/1077 - Train Accuracy: 0.5249, Validation Accuracy: 0.5465, Loss: 0.8763
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.5367, Validation Accuracy: 0.5501, Loss: 0.8618
# Epoch   0 Batch 1071/1077 - Train Accuracy: 0.5426, Validation Accuracy: 0.5543, Loss: 0.8600
# Epoch   1 Batch   51/1077 - Train Accuracy: 0.5273, Validation Accuracy: 0.5600, Loss: 0.7970
# Epoch   1 Batch  102/1077 - Train Accuracy: 0.5863, Validation Accuracy: 0.5909, Loss: 0.7694
# Epoch   1 Batch  153/1077 - Train Accuracy: 0.5742, Validation Accuracy: 0.6040, Loss: 0.7909
# Epoch   1 Batch  204/1077 - Train Accuracy: 0.5988, Validation Accuracy: 0.6023, Loss: 0.7640
# Epoch   1 Batch  255/1077 - Train Accuracy: 0.5852, Validation Accuracy: 0.6136, Loss: 0.7478
# Epoch   1 Batch  306/1077 - Train Accuracy: 0.5949, Validation Accuracy: 0.6087, Loss: 0.6922
# Epoch   1 Batch  357/1077 - Train Accuracy: 0.6187, Validation Accuracy: 0.6065, Loss: 0.6771
# Epoch   1 Batch  408/1077 - Train Accuracy: 0.5977, Validation Accuracy: 0.6168, Loss: 0.7016
# Epoch   1 Batch  459/1077 - Train Accuracy: 0.6257, Validation Accuracy: 0.6261, Loss: 0.6545
# Epoch   1 Batch  510/1077 - Train Accuracy: 0.6293, Validation Accuracy: 0.6204, Loss: 0.6516
# Epoch   1 Batch  561/1077 - Train Accuracy: 0.6499, Validation Accuracy: 0.6328, Loss: 0.6276
# Epoch   1 Batch  612/1077 - Train Accuracy: 0.6533, Validation Accuracy: 0.6278, Loss: 0.6092
# Epoch   1 Batch  663/1077 - Train Accuracy: 0.6031, Validation Accuracy: 0.6310, Loss: 0.6007
# Epoch   1 Batch  714/1077 - Train Accuracy: 0.6243, Validation Accuracy: 0.6431, Loss: 0.5927
# Epoch   1 Batch  765/1077 - Train Accuracy: 0.6555, Validation Accuracy: 0.6484, Loss: 0.5818
# Epoch   1 Batch  816/1077 - Train Accuracy: 0.6859, Validation Accuracy: 0.6516, Loss: 0.6205
# Epoch   1 Batch  867/1077 - Train Accuracy: 0.6012, Validation Accuracy: 0.6424, Loss: 0.6165
# Epoch   1 Batch  918/1077 - Train Accuracy: 0.6749, Validation Accuracy: 0.6488, Loss: 0.5313
# Epoch   1 Batch  969/1077 - Train Accuracy: 0.6797, Validation Accuracy: 0.6545, Loss: 0.5386
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.6535, Validation Accuracy: 0.6523, Loss: 0.5232
# Epoch   1 Batch 1071/1077 - Train Accuracy: 0.6543, Validation Accuracy: 0.6616, Loss: 0.5223
# Epoch   2 Batch   51/1077 - Train Accuracy: 0.6758, Validation Accuracy: 0.6712, Loss: 0.5043
# Epoch   2 Batch  102/1077 - Train Accuracy: 0.7090, Validation Accuracy: 0.6729, Loss: 0.4932
# Epoch   2 Batch  153/1077 - Train Accuracy: 0.6777, Validation Accuracy: 0.6665, Loss: 0.5260
# Epoch   2 Batch  204/1077 - Train Accuracy: 0.6809, Validation Accuracy: 0.6708, Loss: 0.5180
# Epoch   2 Batch  255/1077 - Train Accuracy: 0.6695, Validation Accuracy: 0.6712, Loss: 0.4830
# Epoch   2 Batch  306/1077 - Train Accuracy: 0.6775, Validation Accuracy: 0.6722, Loss: 0.4480
# Epoch   2 Batch  357/1077 - Train Accuracy: 0.6920, Validation Accuracy: 0.6662, Loss: 0.4508
# Epoch   2 Batch  408/1077 - Train Accuracy: 0.6750, Validation Accuracy: 0.6847, Loss: 0.4709
# Epoch   2 Batch  459/1077 - Train Accuracy: 0.7217, Validation Accuracy: 0.6808, Loss: 0.4341
# Epoch   2 Batch  510/1077 - Train Accuracy: 0.6859, Validation Accuracy: 0.6772, Loss: 0.4356
# Epoch   2 Batch  561/1077 - Train Accuracy: 0.7481, Validation Accuracy: 0.6893, Loss: 0.4109
# Epoch   2 Batch  612/1077 - Train Accuracy: 0.7325, Validation Accuracy: 0.6850, Loss: 0.4012
# Epoch   2 Batch  663/1077 - Train Accuracy: 0.7289, Validation Accuracy: 0.6950, Loss: 0.4016
# Epoch   2 Batch  714/1077 - Train Accuracy: 0.7210, Validation Accuracy: 0.6932, Loss: 0.3999
# Epoch   2 Batch  765/1077 - Train Accuracy: 0.7605, Validation Accuracy: 0.7074, Loss: 0.3829
# Epoch   2 Batch  816/1077 - Train Accuracy: 0.7648, Validation Accuracy: 0.7038, Loss: 0.4186
# Epoch   2 Batch  867/1077 - Train Accuracy: 0.7055, Validation Accuracy: 0.6978, Loss: 0.4314
# Epoch   2 Batch  918/1077 - Train Accuracy: 0.7649, Validation Accuracy: 0.7038, Loss: 0.3554
# Epoch   2 Batch  969/1077 - Train Accuracy: 0.7660, Validation Accuracy: 0.7010, Loss: 0.3775
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.7055, Validation Accuracy: 0.6967, Loss: 0.3543
# Epoch   2 Batch 1071/1077 - Train Accuracy: 0.7398, Validation Accuracy: 0.7035, Loss: 0.3470
# Epoch   3 Batch   51/1077 - Train Accuracy: 0.7609, Validation Accuracy: 0.7216, Loss: 0.3479
# Epoch   3 Batch  102/1077 - Train Accuracy: 0.7820, Validation Accuracy: 0.7159, Loss: 0.3376
# Epoch   3 Batch  153/1077 - Train Accuracy: 0.7426, Validation Accuracy: 0.7156, Loss: 0.3724
# Epoch   3 Batch  204/1077 - Train Accuracy: 0.7285, Validation Accuracy: 0.6989, Loss: 0.3724
# Epoch   3 Batch  255/1077 - Train Accuracy: 0.7496, Validation Accuracy: 0.7109, Loss: 0.3375
# Epoch   3 Batch  306/1077 - Train Accuracy: 0.7385, Validation Accuracy: 0.7173, Loss: 0.3128
# Epoch   3 Batch  357/1077 - Train Accuracy: 0.7522, Validation Accuracy: 0.7134, Loss: 0.3153
# Epoch   3 Batch  408/1077 - Train Accuracy: 0.7438, Validation Accuracy: 0.7276, Loss: 0.3195
# Epoch   3 Batch  459/1077 - Train Accuracy: 0.7638, Validation Accuracy: 0.7145, Loss: 0.2916
# Epoch   3 Batch  510/1077 - Train Accuracy: 0.7516, Validation Accuracy: 0.7308, Loss: 0.3019
# Epoch   3 Batch  561/1077 - Train Accuracy: 0.8099, Validation Accuracy: 0.7415, Loss: 0.2769
# Epoch   3 Batch  612/1077 - Train Accuracy: 0.7946, Validation Accuracy: 0.7422, Loss: 0.2730
# Epoch   3 Batch  663/1077 - Train Accuracy: 0.8133, Validation Accuracy: 0.7489, Loss: 0.2673
# Epoch   3 Batch  714/1077 - Train Accuracy: 0.7965, Validation Accuracy: 0.7567, Loss: 0.2655
# Epoch   3 Batch  765/1077 - Train Accuracy: 0.8051, Validation Accuracy: 0.7560, Loss: 0.2545
# Epoch   3 Batch  816/1077 - Train Accuracy: 0.8384, Validation Accuracy: 0.7585, Loss: 0.2917
# Epoch   3 Batch  867/1077 - Train Accuracy: 0.7805, Validation Accuracy: 0.7482, Loss: 0.3002
# Epoch   3 Batch  918/1077 - Train Accuracy: 0.8106, Validation Accuracy: 0.7543, Loss: 0.2422
# Epoch   3 Batch  969/1077 - Train Accuracy: 0.8188, Validation Accuracy: 0.7560, Loss: 0.2572
# Epoch   3 Batch 1020/1077 - Train Accuracy: 0.8102, Validation Accuracy: 0.7681, Loss: 0.2331
# Epoch   3 Batch 1071/1077 - Train Accuracy: 0.8105, Validation Accuracy: 0.7646, Loss: 0.2315
# Epoch   4 Batch   51/1077 - Train Accuracy: 0.8301, Validation Accuracy: 0.7820, Loss: 0.2373
# Epoch   4 Batch  102/1077 - Train Accuracy: 0.8422, Validation Accuracy: 0.7837, Loss: 0.2184
# Epoch   4 Batch  153/1077 - Train Accuracy: 0.8031, Validation Accuracy: 0.7681, Loss: 0.2557
# Epoch   4 Batch  204/1077 - Train Accuracy: 0.8203, Validation Accuracy: 0.7667, Loss: 0.2504
# Epoch   4 Batch  255/1077 - Train Accuracy: 0.8293, Validation Accuracy: 0.7763, Loss: 0.2217
# Epoch   4 Batch  306/1077 - Train Accuracy: 0.8363, Validation Accuracy: 0.7926, Loss: 0.2149
# Epoch   4 Batch  357/1077 - Train Accuracy: 0.8136, Validation Accuracy: 0.7809, Loss: 0.2185
# Epoch   4 Batch  408/1077 - Train Accuracy: 0.8309, Validation Accuracy: 0.7827, Loss: 0.2176
# Epoch   4 Batch  459/1077 - Train Accuracy: 0.8173, Validation Accuracy: 0.8015, Loss: 0.2014
# Epoch   4 Batch  510/1077 - Train Accuracy: 0.8477, Validation Accuracy: 0.7997, Loss: 0.2098
# Epoch   4 Batch  561/1077 - Train Accuracy: 0.8676, Validation Accuracy: 0.8072, Loss: 0.1812
# Epoch   4 Batch  612/1077 - Train Accuracy: 0.8676, Validation Accuracy: 0.8086, Loss: 0.1885
# Epoch   4 Batch  663/1077 - Train Accuracy: 0.8508, Validation Accuracy: 0.8033, Loss: 0.1753
# Epoch   4 Batch  714/1077 - Train Accuracy: 0.8683, Validation Accuracy: 0.8079, Loss: 0.1925
# Epoch   4 Batch  765/1077 - Train Accuracy: 0.8652, Validation Accuracy: 0.8260, Loss: 0.1709
# Epoch   4 Batch  816/1077 - Train Accuracy: 0.8787, Validation Accuracy: 0.8235, Loss: 0.1979
# Epoch   4 Batch  867/1077 - Train Accuracy: 0.8355, Validation Accuracy: 0.8370, Loss: 0.2127
# Epoch   4 Batch  918/1077 - Train Accuracy: 0.8612, Validation Accuracy: 0.8462, Loss: 0.1711
# Epoch   4 Batch  969/1077 - Train Accuracy: 0.8694, Validation Accuracy: 0.8292, Loss: 0.1939
# Epoch   4 Batch 1020/1077 - Train Accuracy: 0.9055, Validation Accuracy: 0.8501, Loss: 0.1622
# Epoch   4 Batch 1071/1077 - Train Accuracy: 0.8781, Validation Accuracy: 0.8530, Loss: 0.1589
# Epoch   5 Batch   51/1077 - Train Accuracy: 0.8797, Validation Accuracy: 0.8445, Loss: 0.1664
# Epoch   5 Batch  102/1077 - Train Accuracy: 0.8867, Validation Accuracy: 0.8391, Loss: 0.1547
# Epoch   5 Batch  153/1077 - Train Accuracy: 0.8656, Validation Accuracy: 0.8370, Loss: 0.1837
# Epoch   5 Batch  204/1077 - Train Accuracy: 0.8438, Validation Accuracy: 0.8310, Loss: 0.1831
# Epoch   5 Batch  255/1077 - Train Accuracy: 0.9008, Validation Accuracy: 0.8537, Loss: 0.1582
# Epoch   5 Batch  306/1077 - Train Accuracy: 0.8943, Validation Accuracy: 0.8423, Loss: 0.1622
# Epoch   5 Batch  357/1077 - Train Accuracy: 0.8672, Validation Accuracy: 0.8377, Loss: 0.1629
# Epoch   5 Batch  408/1077 - Train Accuracy: 0.8879, Validation Accuracy: 0.8413, Loss: 0.1538
# Epoch   5 Batch  459/1077 - Train Accuracy: 0.8914, Validation Accuracy: 0.8384, Loss: 0.1483
# Epoch   5 Batch  510/1077 - Train Accuracy: 0.8688, Validation Accuracy: 0.8615, Loss: 0.1521
# Epoch   5 Batch  561/1077 - Train Accuracy: 0.9025, Validation Accuracy: 0.8544, Loss: 0.1357
# Epoch   5 Batch  612/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.8572, Loss: 0.1272
# Epoch   5 Batch  663/1077 - Train Accuracy: 0.8973, Validation Accuracy: 0.8590, Loss: 0.1264
# Epoch   5 Batch  714/1077 - Train Accuracy: 0.8925, Validation Accuracy: 0.8540, Loss: 0.1362
# Epoch   5 Batch  765/1077 - Train Accuracy: 0.8906, Validation Accuracy: 0.8523, Loss: 0.1262
# Epoch   5 Batch  816/1077 - Train Accuracy: 0.9108, Validation Accuracy: 0.8562, Loss: 0.1392
# Epoch   5 Batch  867/1077 - Train Accuracy: 0.8637, Validation Accuracy: 0.8615, Loss: 0.1609
# Epoch   5 Batch  918/1077 - Train Accuracy: 0.9092, Validation Accuracy: 0.8768, Loss: 0.1212
# Epoch   5 Batch  969/1077 - Train Accuracy: 0.8873, Validation Accuracy: 0.8782, Loss: 0.1412
# Epoch   5 Batch 1020/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.8576, Loss: 0.1097
# Epoch   5 Batch 1071/1077 - Train Accuracy: 0.9141, Validation Accuracy: 0.8846, Loss: 0.1126
# Epoch   6 Batch   51/1077 - Train Accuracy: 0.9027, Validation Accuracy: 0.8778, Loss: 0.1262
# Epoch   6 Batch  102/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.8896, Loss: 0.1106
# Epoch   6 Batch  153/1077 - Train Accuracy: 0.8848, Validation Accuracy: 0.8711, Loss: 0.1447
# Epoch   6 Batch  204/1077 - Train Accuracy: 0.8809, Validation Accuracy: 0.8615, Loss: 0.1519
# Epoch   6 Batch  255/1077 - Train Accuracy: 0.9086, Validation Accuracy: 0.8860, Loss: 0.1119
# Epoch   6 Batch  306/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8707, Loss: 0.1298
# Epoch   6 Batch  357/1077 - Train Accuracy: 0.8810, Validation Accuracy: 0.8750, Loss: 0.1231
# Epoch   6 Batch  408/1077 - Train Accuracy: 0.9195, Validation Accuracy: 0.8793, Loss: 0.1120
# Epoch   6 Batch  459/1077 - Train Accuracy: 0.8981, Validation Accuracy: 0.8757, Loss: 0.1097
# Epoch   6 Batch  510/1077 - Train Accuracy: 0.9203, Validation Accuracy: 0.8896, Loss: 0.1161
# Epoch   6 Batch  561/1077 - Train Accuracy: 0.9174, Validation Accuracy: 0.8686, Loss: 0.1032
# Epoch   6 Batch  612/1077 - Train Accuracy: 0.9271, Validation Accuracy: 0.8743, Loss: 0.0986
# Epoch   6 Batch  663/1077 - Train Accuracy: 0.9031, Validation Accuracy: 0.8920, Loss: 0.0983
# Epoch   6 Batch  714/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.8821, Loss: 0.1064
# Epoch   6 Batch  765/1077 - Train Accuracy: 0.8980, Validation Accuracy: 0.8906, Loss: 0.0988
# Epoch   6 Batch  816/1077 - Train Accuracy: 0.9243, Validation Accuracy: 0.8896, Loss: 0.1104
# Epoch   6 Batch  867/1077 - Train Accuracy: 0.8793, Validation Accuracy: 0.8746, Loss: 0.1336
# Epoch   6 Batch  918/1077 - Train Accuracy: 0.9327, Validation Accuracy: 0.8995, Loss: 0.1019
# Epoch   6 Batch  969/1077 - Train Accuracy: 0.9122, Validation Accuracy: 0.9084, Loss: 0.1150
# Epoch   6 Batch 1020/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9023, Loss: 0.0838
# Epoch   6 Batch 1071/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8839, Loss: 0.0910
# Epoch   7 Batch   51/1077 - Train Accuracy: 0.9168, Validation Accuracy: 0.8956, Loss: 0.0867
# Epoch   7 Batch  102/1077 - Train Accuracy: 0.9203, Validation Accuracy: 0.8935, Loss: 0.0898
# Epoch   7 Batch  153/1077 - Train Accuracy: 0.8980, Validation Accuracy: 0.8938, Loss: 0.1160
# Epoch   7 Batch  204/1077 - Train Accuracy: 0.8898, Validation Accuracy: 0.8839, Loss: 0.1220
# Epoch   7 Batch  255/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.8938, Loss: 0.0867
# Epoch   7 Batch  306/1077 - Train Accuracy: 0.9077, Validation Accuracy: 0.8817, Loss: 0.0885
# Epoch   7 Batch  357/1077 - Train Accuracy: 0.8910, Validation Accuracy: 0.8892, Loss: 0.0927
# Epoch   7 Batch  408/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.8778, Loss: 0.0902
# Epoch   7 Batch  459/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.9041, Loss: 0.0775
# Epoch   7 Batch  510/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.8952, Loss: 0.0854
# Epoch   7 Batch  561/1077 - Train Accuracy: 0.9271, Validation Accuracy: 0.8803, Loss: 0.0739
# Epoch   7 Batch  612/1077 - Train Accuracy: 0.9308, Validation Accuracy: 0.8963, Loss: 0.0732
# Epoch   7 Batch  663/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.8931, Loss: 0.0779
# Epoch   7 Batch  714/1077 - Train Accuracy: 0.9286, Validation Accuracy: 0.8892, Loss: 0.0793
# Epoch   7 Batch  765/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.9073, Loss: 0.0705
# Epoch   7 Batch  816/1077 - Train Accuracy: 0.9416, Validation Accuracy: 0.9041, Loss: 0.0800
# Epoch   7 Batch  867/1077 - Train Accuracy: 0.8922, Validation Accuracy: 0.8995, Loss: 0.1192
# Epoch   7 Batch  918/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9023, Loss: 0.0738
# Epoch   7 Batch  969/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8899, Loss: 0.0988
# Epoch   7 Batch 1020/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9038, Loss: 0.0669
# Epoch   7 Batch 1071/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.8974, Loss: 0.0651
# Epoch   8 Batch   51/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.9144, Loss: 0.0708
# Epoch   8 Batch  102/1077 - Train Accuracy: 0.9410, Validation Accuracy: 0.9197, Loss: 0.0713
# Epoch   8 Batch  153/1077 - Train Accuracy: 0.9160, Validation Accuracy: 0.9062, Loss: 0.0973
# Epoch   8 Batch  204/1077 - Train Accuracy: 0.9086, Validation Accuracy: 0.9052, Loss: 0.1049
# Epoch   8 Batch  255/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9034, Loss: 0.0642
# Epoch   8 Batch  306/1077 - Train Accuracy: 0.9241, Validation Accuracy: 0.9091, Loss: 0.0815
# Epoch   8 Batch  357/1077 - Train Accuracy: 0.8925, Validation Accuracy: 0.9048, Loss: 0.0800
# Epoch   8 Batch  408/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9016, Loss: 0.0775
# Epoch   8 Batch  459/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.9151, Loss: 0.0713
# Epoch   8 Batch  510/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9094, Loss: 0.0687
# Epoch   8 Batch  561/1077 - Train Accuracy: 0.9330, Validation Accuracy: 0.9002, Loss: 0.0529
# Epoch   8 Batch  612/1077 - Train Accuracy: 0.9364, Validation Accuracy: 0.8974, Loss: 0.0639
# Epoch   8 Batch  663/1077 - Train Accuracy: 0.9254, Validation Accuracy: 0.8967, Loss: 0.0660
# Epoch   8 Batch  714/1077 - Train Accuracy: 0.9416, Validation Accuracy: 0.9130, Loss: 0.0702
# Epoch   8 Batch  765/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9173, Loss: 0.0617
# Epoch   8 Batch  816/1077 - Train Accuracy: 0.9482, Validation Accuracy: 0.9109, Loss: 0.0784
# Epoch   8 Batch  867/1077 - Train Accuracy: 0.9031, Validation Accuracy: 0.9134, Loss: 0.1011
# Epoch   8 Batch  918/1077 - Train Accuracy: 0.9342, Validation Accuracy: 0.9162, Loss: 0.0676
# Epoch   8 Batch  969/1077 - Train Accuracy: 0.9103, Validation Accuracy: 0.9137, Loss: 0.0780
# Epoch   8 Batch 1020/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9279, Loss: 0.0505
# Epoch   8 Batch 1071/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9165, Loss: 0.0552
# Epoch   9 Batch   51/1077 - Train Accuracy: 0.9016, Validation Accuracy: 0.9279, Loss: 0.0629
# Epoch   9 Batch  102/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9286, Loss: 0.0601
# Epoch   9 Batch  153/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9169, Loss: 0.0727
# Epoch   9 Batch  204/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9098, Loss: 0.0830
# Epoch   9 Batch  255/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9144, Loss: 0.0530
# Epoch   9 Batch  306/1077 - Train Accuracy: 0.9237, Validation Accuracy: 0.9102, Loss: 0.0700
# Epoch   9 Batch  357/1077 - Train Accuracy: 0.9048, Validation Accuracy: 0.9080, Loss: 0.0640
# Epoch   9 Batch  408/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.9105, Loss: 0.0690
# Epoch   9 Batch  459/1077 - Train Accuracy: 0.9338, Validation Accuracy: 0.9098, Loss: 0.0606
# Epoch   9 Batch  510/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.9169, Loss: 0.0635
# Epoch   9 Batch  561/1077 - Train Accuracy: 0.9561, Validation Accuracy: 0.9112, Loss: 0.0488
# Epoch   9 Batch  612/1077 - Train Accuracy: 0.9323, Validation Accuracy: 0.9098, Loss: 0.0526
# Epoch   9 Batch  663/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9201, Loss: 0.0543
# Epoch   9 Batch  714/1077 - Train Accuracy: 0.9524, Validation Accuracy: 0.9141, Loss: 0.0553
# Epoch   9 Batch  765/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9457, Loss: 0.0616
# Epoch   9 Batch  816/1077 - Train Accuracy: 0.9581, Validation Accuracy: 0.9300, Loss: 0.0692
# Epoch   9 Batch  867/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.9077, Loss: 0.1001
# Epoch   9 Batch  918/1077 - Train Accuracy: 0.9334, Validation Accuracy: 0.9261, Loss: 0.0586
# Epoch   9 Batch  969/1077 - Train Accuracy: 0.9237, Validation Accuracy: 0.9151, Loss: 0.0690
# Epoch   9 Batch 1020/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9350, Loss: 0.0450
# Epoch   9 Batch 1071/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9276, Loss: 0.0580
# Epoch  10 Batch   51/1077 - Train Accuracy: 0.9191, Validation Accuracy: 0.9389, Loss: 0.0580
# Epoch  10 Batch  102/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9222, Loss: 0.0514
# Epoch  10 Batch  153/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9254, Loss: 0.0648
# Epoch  10 Batch  204/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.9173, Loss: 0.0832
# Epoch  10 Batch  255/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9229, Loss: 0.0493
# Epoch  10 Batch  306/1077 - Train Accuracy: 0.9345, Validation Accuracy: 0.9368, Loss: 0.0617
# Epoch  10 Batch  357/1077 - Train Accuracy: 0.9170, Validation Accuracy: 0.9272, Loss: 0.0570
# Epoch  10 Batch  408/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9094, Loss: 0.0590
# Epoch  10 Batch  459/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9279, Loss: 0.0524
# Epoch  10 Batch  510/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9276, Loss: 0.0517
# Epoch  10 Batch  561/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9137, Loss: 0.0464
# Epoch  10 Batch  612/1077 - Train Accuracy: 0.9442, Validation Accuracy: 0.9268, Loss: 0.0515
# Epoch  10 Batch  663/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9279, Loss: 0.0438
# Epoch  10 Batch  714/1077 - Train Accuracy: 0.9427, Validation Accuracy: 0.9311, Loss: 0.0511
# Epoch  10 Batch  765/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.9457, Loss: 0.0553
# Epoch  10 Batch  816/1077 - Train Accuracy: 0.9572, Validation Accuracy: 0.9268, Loss: 0.0517
# Epoch  10 Batch  867/1077 - Train Accuracy: 0.9199, Validation Accuracy: 0.9201, Loss: 0.0835
# Epoch  10 Batch  918/1077 - Train Accuracy: 0.9342, Validation Accuracy: 0.9311, Loss: 0.0550
# Epoch  10 Batch  969/1077 - Train Accuracy: 0.9260, Validation Accuracy: 0.9311, Loss: 0.0677
# Epoch  10 Batch 1020/1077 - Train Accuracy: 0.9715, Validation Accuracy: 0.9318, Loss: 0.0401
# Epoch  10 Batch 1071/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9400, Loss: 0.0456
# Epoch  11 Batch   51/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.9329, Loss: 0.0512
# Epoch  11 Batch  102/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9276, Loss: 0.0483
# Epoch  11 Batch  153/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9375, Loss: 0.0536
# Epoch  11 Batch  204/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.9187, Loss: 0.0684
# Epoch  11 Batch  255/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9343, Loss: 0.0451
# Epoch  11 Batch  306/1077 - Train Accuracy: 0.9278, Validation Accuracy: 0.9403, Loss: 0.0604
# Epoch  11 Batch  357/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9435, Loss: 0.0558
# Epoch  11 Batch  408/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9212, Loss: 0.0568
# Epoch  11 Batch  459/1077 - Train Accuracy: 0.9416, Validation Accuracy: 0.9165, Loss: 0.0433
# Epoch  11 Batch  510/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9439, Loss: 0.0490
# Epoch  11 Batch  561/1077 - Train Accuracy: 0.9550, Validation Accuracy: 0.9208, Loss: 0.0413
# Epoch  11 Batch  612/1077 - Train Accuracy: 0.9479, Validation Accuracy: 0.9272, Loss: 0.0444
# Epoch  11 Batch  663/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9407, Loss: 0.0383
# Epoch  11 Batch  714/1077 - Train Accuracy: 0.9572, Validation Accuracy: 0.9368, Loss: 0.0442
# Epoch  11 Batch  765/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9521, Loss: 0.0453
# Epoch  11 Batch  816/1077 - Train Accuracy: 0.9626, Validation Accuracy: 0.9474, Loss: 0.0539
# Epoch  11 Batch  867/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9418, Loss: 0.0775
# Epoch  11 Batch  918/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9450, Loss: 0.0446
# Epoch  11 Batch  969/1077 - Train Accuracy: 0.9330, Validation Accuracy: 0.9311, Loss: 0.0675
# Epoch  11 Batch 1020/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9528, Loss: 0.0369
# Epoch  11 Batch 1071/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9304, Loss: 0.0422
# Epoch  12 Batch   51/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.9371, Loss: 0.0504
# Epoch  12 Batch  102/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9471, Loss: 0.0410
# Epoch  12 Batch  153/1077 - Train Accuracy: 0.9313, Validation Accuracy: 0.9506, Loss: 0.0547
# Epoch  12 Batch  204/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.9354, Loss: 0.0709
# Epoch  12 Batch  255/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9386, Loss: 0.0424
# Epoch  12 Batch  306/1077 - Train Accuracy: 0.9334, Validation Accuracy: 0.9439, Loss: 0.0479
# Epoch  12 Batch  357/1077 - Train Accuracy: 0.9412, Validation Accuracy: 0.9467, Loss: 0.0549
# Epoch  12 Batch  408/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9442, Loss: 0.0495
# Epoch  12 Batch  459/1077 - Train Accuracy: 0.9408, Validation Accuracy: 0.9467, Loss: 0.0495
# Epoch  12 Batch  510/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.9478, Loss: 0.0410
# Epoch  12 Batch  561/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9396, Loss: 0.0323
# Epoch  12 Batch  612/1077 - Train Accuracy: 0.9468, Validation Accuracy: 0.9453, Loss: 0.0338
# Epoch  12 Batch  663/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9386, Loss: 0.0407
# Epoch  12 Batch  714/1077 - Train Accuracy: 0.9624, Validation Accuracy: 0.9460, Loss: 0.0426
# Epoch  12 Batch  765/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9474, Loss: 0.0508
# Epoch  12 Batch  816/1077 - Train Accuracy: 0.9622, Validation Accuracy: 0.9538, Loss: 0.0477
# Epoch  12 Batch  867/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9492, Loss: 0.0808
# Epoch  12 Batch  918/1077 - Train Accuracy: 0.9420, Validation Accuracy: 0.9467, Loss: 0.0359
# Epoch  12 Batch  969/1077 - Train Accuracy: 0.9267, Validation Accuracy: 0.9482, Loss: 0.0568
# Epoch  12 Batch 1020/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9560, Loss: 0.0379
# Epoch  12 Batch 1071/1077 - Train Accuracy: 0.9410, Validation Accuracy: 0.9354, Loss: 0.0417
# Epoch  13 Batch   51/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9553, Loss: 0.0388
# Epoch  13 Batch  102/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.9457, Loss: 0.0398
# Epoch  13 Batch  153/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9581, Loss: 0.0477
# Epoch  13 Batch  204/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9460, Loss: 0.0629
# Epoch  13 Batch  255/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9613, Loss: 0.0358
# Epoch  13 Batch  306/1077 - Train Accuracy: 0.9405, Validation Accuracy: 0.9485, Loss: 0.0505
# Epoch  13 Batch  357/1077 - Train Accuracy: 0.9353, Validation Accuracy: 0.9244, Loss: 0.0451
# Epoch  13 Batch  408/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9450, Loss: 0.0482
# Epoch  13 Batch  459/1077 - Train Accuracy: 0.9427, Validation Accuracy: 0.9439, Loss: 0.0439
# Epoch  13 Batch  510/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9535, Loss: 0.0376
# Epoch  13 Batch  561/1077 - Train Accuracy: 0.9576, Validation Accuracy: 0.9432, Loss: 0.0338
# Epoch  13 Batch  612/1077 - Train Accuracy: 0.9546, Validation Accuracy: 0.9492, Loss: 0.0329
# Epoch  13 Batch  663/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9478, Loss: 0.0359
# Epoch  13 Batch  714/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9645, Loss: 0.0358
# Epoch  13 Batch  765/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9567, Loss: 0.0401
# Epoch  13 Batch  816/1077 - Train Accuracy: 0.9638, Validation Accuracy: 0.9553, Loss: 0.0535
# Epoch  13 Batch  867/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9528, Loss: 0.0790
# Epoch  13 Batch  918/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9634, Loss: 0.0360
# Epoch  13 Batch  969/1077 - Train Accuracy: 0.9368, Validation Accuracy: 0.9474, Loss: 0.0543
# Epoch  13 Batch 1020/1077 - Train Accuracy: 0.9785, Validation Accuracy: 0.9588, Loss: 0.0340
# Epoch  13 Batch 1071/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9542, Loss: 0.0415
# Epoch  14 Batch   51/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.9496, Loss: 0.0433
# Epoch  14 Batch  102/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9482, Loss: 0.0377
# Epoch  14 Batch  153/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9560, Loss: 0.0467
# Epoch  14 Batch  204/1077 - Train Accuracy: 0.9313, Validation Accuracy: 0.9379, Loss: 0.0598
# Epoch  14 Batch  255/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9624, Loss: 0.0423
# Epoch  14 Batch  306/1077 - Train Accuracy: 0.9397, Validation Accuracy: 0.9531, Loss: 0.0528
# Epoch  14 Batch  357/1077 - Train Accuracy: 0.9475, Validation Accuracy: 0.9428, Loss: 0.0426
# Epoch  14 Batch  408/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9553, Loss: 0.0474
# Epoch  14 Batch  459/1077 - Train Accuracy: 0.9494, Validation Accuracy: 0.9524, Loss: 0.0393
# Epoch  14 Batch  510/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9503, Loss: 0.0396
# Epoch  14 Batch  561/1077 - Train Accuracy: 0.9583, Validation Accuracy: 0.9457, Loss: 0.0323
# Epoch  14 Batch  612/1077 - Train Accuracy: 0.9546, Validation Accuracy: 0.9680, Loss: 0.0337
# Epoch  14 Batch  663/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9485, Loss: 0.0393
# Epoch  14 Batch  714/1077 - Train Accuracy: 0.9635, Validation Accuracy: 0.9585, Loss: 0.0380
# Epoch  14 Batch  765/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9528, Loss: 0.0385
# Epoch  14 Batch  816/1077 - Train Accuracy: 0.9548, Validation Accuracy: 0.9531, Loss: 0.0401
# Epoch  14 Batch  867/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9691, Loss: 0.0849
# Epoch  14 Batch  918/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9556, Loss: 0.0384
# Epoch  14 Batch  969/1077 - Train Accuracy: 0.9420, Validation Accuracy: 0.9613, Loss: 0.0560
# Epoch  14 Batch 1020/1077 - Train Accuracy: 0.9707, Validation Accuracy: 0.9624, Loss: 0.0338
# Epoch  14 Batch 1071/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9592, Loss: 0.0340
# Model Trained and Saved

# %%
# Print the loss and test/validation accuracies.

# Increase size of the subplots.
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 24 
fig_size[1] = 16
plt.rcParams["figure.figsize"] = fig_size

# ----- START ----- #
print("# Batches: {}".format(len(batches)))
loss_plot = plt.subplot(211)
loss_plot.set_title('Loss')
loss_plot.plot(batches, losses, 'g')
loss_plot.set_xlim([batches[0], batches[-1]])

acc_plot = plt.subplot(212)
acc_plot.set_title('Accuracy')
acc_plot.plot(batches, train_accs, 'r', label='Training Accuracy')
acc_plot.plot(batches, valid_accs, 'x', label='Validation Accuracy')
acc_plot.set_ylim([0, 1.0])
acc_plot.set_xlim([batches[0], batches[-1]])
acc_plot.legend(loc=4)

plt.tight_layout()
plt.show()
# ----- END ----- #
# Out:
# # Batches: 315

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    unk_id = vocab_to_int['<UNK>']
    return [vocab_to_int.get(w, unk_id) for w in sentence.lower().split(' ')]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old black truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [85, 131, 139, 8, 61, 72, 153]
#   English Words: ['he', 'saw', 'a', 'old', 'black', 'truck', '.']
#
# Prediction
#   Word Ids:      [22, 58, 49, 310, 321, 160, 1]
#   French Words: il a vu un vieux . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
