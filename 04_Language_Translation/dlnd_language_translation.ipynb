# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # Use an ID of 0 if a word is not contained in source_vocab_to_int or target_vocab_to_int.
    source_id_text = [[source_vocab_to_int.get(w, 0) for w in s.split(' ')] for s in source_text.split('\n')]
       
    target_id_text = []
    for s in target_text.split('\n'):
        ids = [target_vocab_to_int.get(w, 0) for w in s.split(' ')]
        ids.append(target_vocab_to_int['<EOS>'])
        target_id_text.append(ids)
    
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# /Users/d065035/anaconda3/envs/tensorflow_1.1/lib/python3.6/site-packages/ipykernel/__main__.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    input_data = tf.placeholder(tf.int32, [None, None], name="input")
    targets = tf.placeholder(tf.int32, [None, None], name="targets")
    learning_rate = tf.placeholder(tf.float32, name="learning_rate")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    target_sequence_length = tf.placeholder(tf.int32, (None,), name="target_sequence_length")
    max_target_len = tf.reduce_max(target_sequence_length, name="max_target_len")
    source_sequence_length = tf.placeholder(tf.int32, (None,), name="source_sequence_length")
    
    return input_data, targets, learning_rate, keep_prob, target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    sliced = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    go = tf.fill([batch_size, 1], target_vocab_to_int['<GO>'])
    return tf.concat([go, sliced], 1)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    
    # Shape: [batch size, sequence length, embedding size]
    embedded_input = tf.contrib.layers.embed_sequence(ids=rnn_inputs,
                                                      vocab_size=source_vocab_size,
                                                      embed_dim=encoding_embedding_size)
    
    def lstm_cell(num_units):
        cell = tf.contrib.rnn.LSTMCell(num_units=num_units,
                                       initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return tf.contrib.rnn.DropoutWrapper(cell=cell, input_keep_prob=keep_prob)
    
    lstm_cells = [lstm_cell(rnn_size) for _ in range(num_layers)]
    rnn_cells = tf.contrib.rnn.MultiRNNCell(cells=lstm_cells)
    
    output, state = tf.nn.dynamic_rnn(cell=rnn_cells,
                                      inputs=embedded_input,
                                      sequence_length=source_sequence_length,
                                      dtype=tf.float32)
    return output, state


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_target_sequence_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    
    # I don't know how to use keep_prob here. Is it required?
    
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input, 
                                                        sequence_length=target_sequence_length)
    
    training_decoder = tf.contrib.seq2seq.BasicDecoder(cell=dec_cell,
                                                       helper=training_helper,
                                                       initial_state=encoder_state,
                                                       output_layer=output_layer)
    
    training_logits, _ = tf.contrib.seq2seq.dynamic_decode(decoder=training_decoder,
                                                           impute_finished=True,
                                                           maximum_iterations=max_target_sequence_length)
    
    return training_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    
    # I don't know how to use keep_prob here. Is it required?
    
    start_token=tf.constant([start_of_sequence_id], dtype=tf.int32)
    start_tokens=tf.tile(start_token, [batch_size], name="start_tokens")
    
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(embedding=dec_embeddings,
                                                                start_tokens=start_tokens,
                                                                end_token=end_of_sequence_id)
    
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(cell=dec_cell,
                                                        helper=inference_helper,
                                                        initial_state=encoder_state,
                                                        output_layer=output_layer)
    
    inference_logits, _ = tf.contrib.seq2seq.dynamic_decode(decoder=inference_decoder,
                                                            impute_finished=True,
                                                            maximum_iterations=max_target_sequence_length)
    
    return inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """ 
    
    # Embed the target sequences.
    # ---------------------------
    # Shape: [vocab_size, embedding_size]
    embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    # Shape: [batch_size, sequence_length, embedding_size]
    embedding_lookup = tf.nn.embedding_lookup(params=embeddings, ids=dec_input)
        
    # Construct the decoder LSTM cells.
    # ---------------------------------
    def lstm_cell(num_units):
        cell = tf.contrib.rnn.LSTMCell(num_units=num_units,
                                       initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return tf.contrib.rnn.DropoutWrapper(cell=cell, input_keep_prob=keep_prob)
    
    lstm_cells = [lstm_cell(rnn_size) for _ in range(num_layers)]
    rnn_cells = tf.contrib.rnn.MultiRNNCell(cells=lstm_cells)
    
    # Create an output layer.
    # -----------------------
    output_layer = Dense(units=target_vocab_size,
                         kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1))
    
    # Get the training logits.
    # ------------------------
    with tf.variable_scope("decode"):
        trainig_logits = decoding_layer_train(encoder_state=encoder_state,
                                              dec_cell=rnn_cells,
                                              dec_embed_input=embedding_lookup,
                                              target_sequence_length=target_sequence_length,
                                              max_target_sequence_length=max_target_sequence_length,
                                              output_layer=output_layer,
                                              keep_prob=keep_prob)
    
    # Get the inference logits.
    # -------------------------
    with tf.variable_scope("decode", reuse=True):
        inference_logits = decoding_layer_infer(encoder_state=encoder_state,
                                                dec_cell=rnn_cells,
                                                dec_embeddings=embeddings,
                                                start_of_sequence_id=target_vocab_to_int["<GO>"],
                                                end_of_sequence_id=target_vocab_to_int["<EOS>"],
                                                max_target_sequence_length=max_target_sequence_length,
                                                vocab_size=target_vocab_size,
                                                output_layer=output_layer,
                                                batch_size=batch_size,
                                                keep_prob=keep_prob)

    
    return trainig_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network.
    :param input_data: Input placeholder.
    :param target_data: Target placeholder.
    :param keep_prob: Dropout keep probability placeholder.
    :param batch_size: Batch size.
    :param source_sequence_length: Sequence lengths of source sequences in the batch.
    :param target_sequence_length: Sequence lengths of target sequences in the batch.
    :param source_vocab_size: Source vocabulary size.
    :param target_vocab_size: Target vocabulary size.
    :param enc_embedding_size: Decoder embedding size.
    :param dec_embedding_size: Encoder embedding size.
    :param rnn_size: RNN size.
    :param num_layers: Number of layers.
    :param target_vocab_to_int: Dictionary to go from target words to IDs.
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    print("input_data: {}".format(input_data))  # Shape: [batch_size, sequence_length]
    print("target_data: {}".format(input_data))  # Shape: [batch_size, sequence_length]
    print("keep_prob: {}".format(keep_prob))
    print("batch_size: {}".format(batch_size))    
    print("source_sequence_length: {}".format(source_sequence_length))
    print("target_sequence_length: {}".format(target_sequence_length))
    print("source_vocab_size: {}".format(source_vocab_size))
    print("target_vocab_size: {}".format(target_vocab_size))
    print("enc_embedding_size: {}".format(enc_embedding_size)) 
    print("dec_embedding_size: {}".format(dec_embedding_size)) 
    print("rnn_size: {}".format(rnn_size))
    print("num_layers: {}".format(num_layers))
    
    # Encode the input.
    encoder_output, encoder_state = encoding_layer(rnn_inputs=input_data,
                                                   rnn_size=rnn_size,
                                                   num_layers=num_layers,
                                                   keep_prob=keep_prob,
                                                   source_sequence_length=source_sequence_length,
                                                   source_vocab_size=source_vocab_size,
                                                   encoding_embedding_size=enc_embedding_size)
    
    # Process the target data.    
    decoder_input = process_decoder_input(target_data=target_data,
                                          target_vocab_to_int=target_vocab_to_int,
                                          batch_size=batch_size)
        
    # Decode the encoded input.                    
    training_logits, inference_logits = decoding_layer(dec_input=decoder_input,
                                                       encoder_state=encoder_state,
                                                       target_sequence_length=target_sequence_length,
                                                       max_target_sequence_length=max_target_sentence_length,
                                                       rnn_size=rnn_size,
                                                       num_layers=num_layers,
                                                       target_vocab_to_int=target_vocab_to_int,
                                                       target_vocab_size=target_vocab_size,
                                                       batch_size=batch_size,
                                                       keep_prob=keep_prob,
                                                       decoding_embedding_size=dec_embedding_size)    
    
    return training_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# input_data: Tensor("Placeholder_6:0", shape=(64, 22), dtype=int32)
# target_data: Tensor("Placeholder_6:0", shape=(64, 22), dtype=int32)
# keep_prob: Tensor("Placeholder_8:0", dtype=float32)
# batch_size: 64
# source_sequence_length: Tensor("source_sequence_length:0", shape=(?,), dtype=int32)
# target_sequence_length: Tensor("target_sequence_length:0", shape=(?,), dtype=int32)
# source_vocab_size: 300
# target_vocab_size: 300
# enc_embedding_size: 100
# dec_embedding_size: 100
# rnn_size: 512
# num_layers: 3
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of epochs.
epochs = 30

# Batch size.
batch_size = 128

# RNN size, i.e. the number of hidden units in the LSTM cells.
rnn_size = 64

# Number of LSTM layers.
num_layers = 2

# Embedding sizes.
# I read somewhere that the embedding size should be bigger than the RNN size.
# I'm using double the number of hidden units in the LSTMs.
encoding_embedding_size = 128
decoding_embedding_size = 128

# Learning rate.
learning_rate = 0.001

# Dropout keep probability.
keep_probability = 0.6

# How many steps between each debug statement?
display_step = 51

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)
# Out:
# input_data: Tensor("ReverseV2:0", shape=(?, ?), dtype=int32)
# target_data: Tensor("ReverseV2:0", shape=(?, ?), dtype=int32)
# keep_prob: Tensor("keep_prob:0", dtype=float32)
# batch_size: 128
# source_sequence_length: Tensor("source_sequence_length:0", shape=(?,), dtype=int32)
# target_sequence_length: Tensor("target_sequence_length:0", shape=(?,), dtype=int32)
# source_vocab_size: 231
# target_vocab_size: 358
# enc_embedding_size: 128
# dec_embedding_size: 128
# rnn_size: 64
# num_layers: 2

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
# I'm addinga few things to plot the loss and test/validation accuracies.
# See the START and END delimiters.

# ----- START ----- #
# %matplotlib inline

import matplotlib.pyplot as plt

batches = []
losses = []
train_accs = []
valid_accs = []
# ----- END ----- #

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:

                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                # ----- START ----- #
                previous_batch = batches[-1] if batches else 0
                batches.append(display_step + previous_batch)
                losses.append(loss)
                train_accs.append(train_acc)
                valid_accs.append(valid_acc)
                # ----- END ----- #

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)

    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   51/1077 - Train Accuracy: 0.3230, Validation Accuracy: 0.3651, Loss: 3.2784
# Epoch   0 Batch  102/1077 - Train Accuracy: 0.3461, Validation Accuracy: 0.3814, Loss: 2.9182
# Epoch   0 Batch  153/1077 - Train Accuracy: 0.3527, Validation Accuracy: 0.4137, Loss: 2.8297
# Epoch   0 Batch  204/1077 - Train Accuracy: 0.3852, Validation Accuracy: 0.4414, Loss: 2.6037
# Epoch   0 Batch  255/1077 - Train Accuracy: 0.4164, Validation Accuracy: 0.4734, Loss: 2.4771
# Epoch   0 Batch  306/1077 - Train Accuracy: 0.4323, Validation Accuracy: 0.4709, Loss: 2.2497
# Epoch   0 Batch  357/1077 - Train Accuracy: 0.4799, Validation Accuracy: 0.4840, Loss: 2.0700
# Epoch   0 Batch  408/1077 - Train Accuracy: 0.4422, Validation Accuracy: 0.4911, Loss: 2.1031
# Epoch   0 Batch  459/1077 - Train Accuracy: 0.4914, Validation Accuracy: 0.5099, Loss: 1.8805
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.4707, Validation Accuracy: 0.5096, Loss: 1.7711
# Epoch   0 Batch  561/1077 - Train Accuracy: 0.4766, Validation Accuracy: 0.4968, Loss: 1.5413
# Epoch   0 Batch  612/1077 - Train Accuracy: 0.5052, Validation Accuracy: 0.5245, Loss: 1.3670
# Epoch   0 Batch  663/1077 - Train Accuracy: 0.4570, Validation Accuracy: 0.5192, Loss: 1.3194
# Epoch   0 Batch  714/1077 - Train Accuracy: 0.4591, Validation Accuracy: 0.5263, Loss: 1.2301
# Epoch   0 Batch  765/1077 - Train Accuracy: 0.5094, Validation Accuracy: 0.5341, Loss: 1.1105
# Epoch   0 Batch  816/1077 - Train Accuracy: 0.4889, Validation Accuracy: 0.5291, Loss: 1.1238
# Epoch   0 Batch  867/1077 - Train Accuracy: 0.4598, Validation Accuracy: 0.5298, Loss: 1.0845
# Epoch   0 Batch  918/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5426, Loss: 0.9388
# Epoch   0 Batch  969/1077 - Train Accuracy: 0.5246, Validation Accuracy: 0.5472, Loss: 0.9236
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.5051, Validation Accuracy: 0.5547, Loss: 0.9074
# Epoch   0 Batch 1071/1077 - Train Accuracy: 0.5047, Validation Accuracy: 0.5643, Loss: 0.9092
# Epoch   1 Batch   51/1077 - Train Accuracy: 0.5309, Validation Accuracy: 0.5582, Loss: 0.8342
# Epoch   1 Batch  102/1077 - Train Accuracy: 0.5598, Validation Accuracy: 0.5614, Loss: 0.8321
# Epoch   1 Batch  153/1077 - Train Accuracy: 0.5566, Validation Accuracy: 0.5682, Loss: 0.8600
# Epoch   1 Batch  204/1077 - Train Accuracy: 0.5379, Validation Accuracy: 0.5618, Loss: 0.8341
# Epoch   1 Batch  255/1077 - Train Accuracy: 0.5500, Validation Accuracy: 0.5763, Loss: 0.7954
# Epoch   1 Batch  306/1077 - Train Accuracy: 0.5577, Validation Accuracy: 0.5866, Loss: 0.7429
# Epoch   1 Batch  357/1077 - Train Accuracy: 0.5852, Validation Accuracy: 0.5888, Loss: 0.7252
# Epoch   1 Batch  408/1077 - Train Accuracy: 0.5625, Validation Accuracy: 0.5835, Loss: 0.7563
# Epoch   1 Batch  459/1077 - Train Accuracy: 0.5867, Validation Accuracy: 0.5888, Loss: 0.7053
# Epoch   1 Batch  510/1077 - Train Accuracy: 0.5934, Validation Accuracy: 0.5884, Loss: 0.7025
# Epoch   1 Batch  561/1077 - Train Accuracy: 0.6276, Validation Accuracy: 0.5987, Loss: 0.6803
# Epoch   1 Batch  612/1077 - Train Accuracy: 0.6220, Validation Accuracy: 0.5945, Loss: 0.6666
# Epoch   1 Batch  663/1077 - Train Accuracy: 0.5750, Validation Accuracy: 0.5945, Loss: 0.6703
# Epoch   1 Batch  714/1077 - Train Accuracy: 0.5718, Validation Accuracy: 0.6065, Loss: 0.6720
# Epoch   1 Batch  765/1077 - Train Accuracy: 0.6000, Validation Accuracy: 0.6040, Loss: 0.6456
# Epoch   1 Batch  816/1077 - Train Accuracy: 0.6328, Validation Accuracy: 0.6168, Loss: 0.6969
# Epoch   1 Batch  867/1077 - Train Accuracy: 0.5680, Validation Accuracy: 0.6161, Loss: 0.6932
# Epoch   1 Batch  918/1077 - Train Accuracy: 0.6611, Validation Accuracy: 0.6222, Loss: 0.6039
# Epoch   1 Batch  969/1077 - Train Accuracy: 0.6477, Validation Accuracy: 0.6296, Loss: 0.6182
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.6145, Validation Accuracy: 0.6246, Loss: 0.6206
# Epoch   1 Batch 1071/1077 - Train Accuracy: 0.6254, Validation Accuracy: 0.6491, Loss: 0.6103
# Epoch   2 Batch   51/1077 - Train Accuracy: 0.6562, Validation Accuracy: 0.6413, Loss: 0.5874
# Epoch   2 Batch  102/1077 - Train Accuracy: 0.6762, Validation Accuracy: 0.6495, Loss: 0.5862
# Epoch   2 Batch  153/1077 - Train Accuracy: 0.6629, Validation Accuracy: 0.6460, Loss: 0.6048
# Epoch   2 Batch  204/1077 - Train Accuracy: 0.6379, Validation Accuracy: 0.6584, Loss: 0.6067
# Epoch   2 Batch  255/1077 - Train Accuracy: 0.6434, Validation Accuracy: 0.6577, Loss: 0.5646
# Epoch   2 Batch  306/1077 - Train Accuracy: 0.6477, Validation Accuracy: 0.6467, Loss: 0.5397
# Epoch   2 Batch  357/1077 - Train Accuracy: 0.6771, Validation Accuracy: 0.6651, Loss: 0.5185
# Epoch   2 Batch  408/1077 - Train Accuracy: 0.6426, Validation Accuracy: 0.6630, Loss: 0.5414
# Epoch   2 Batch  459/1077 - Train Accuracy: 0.6812, Validation Accuracy: 0.6612, Loss: 0.5019
# Epoch   2 Batch  510/1077 - Train Accuracy: 0.6602, Validation Accuracy: 0.6729, Loss: 0.5056
# Epoch   2 Batch  561/1077 - Train Accuracy: 0.7165, Validation Accuracy: 0.6790, Loss: 0.4837
# Epoch   2 Batch  612/1077 - Train Accuracy: 0.6834, Validation Accuracy: 0.6747, Loss: 0.4778
# Epoch   2 Batch  663/1077 - Train Accuracy: 0.6547, Validation Accuracy: 0.6726, Loss: 0.4619
# Epoch   2 Batch  714/1077 - Train Accuracy: 0.6704, Validation Accuracy: 0.6669, Loss: 0.4651
# Epoch   2 Batch  765/1077 - Train Accuracy: 0.7070, Validation Accuracy: 0.6733, Loss: 0.4491
# Epoch   2 Batch  816/1077 - Train Accuracy: 0.7257, Validation Accuracy: 0.6918, Loss: 0.4984
# Epoch   2 Batch  867/1077 - Train Accuracy: 0.6766, Validation Accuracy: 0.6733, Loss: 0.4970
# Epoch   2 Batch  918/1077 - Train Accuracy: 0.7314, Validation Accuracy: 0.7028, Loss: 0.4230
# Epoch   2 Batch  969/1077 - Train Accuracy: 0.7202, Validation Accuracy: 0.6999, Loss: 0.4426
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.7266, Validation Accuracy: 0.7088, Loss: 0.4347
# Epoch   2 Batch 1071/1077 - Train Accuracy: 0.7105, Validation Accuracy: 0.7127, Loss: 0.4255
# Epoch   3 Batch   51/1077 - Train Accuracy: 0.7277, Validation Accuracy: 0.7156, Loss: 0.4265
# Epoch   3 Batch  102/1077 - Train Accuracy: 0.7496, Validation Accuracy: 0.7177, Loss: 0.4127
# Epoch   3 Batch  153/1077 - Train Accuracy: 0.7156, Validation Accuracy: 0.7120, Loss: 0.4333
# Epoch   3 Batch  204/1077 - Train Accuracy: 0.7176, Validation Accuracy: 0.7180, Loss: 0.4316
# Epoch   3 Batch  255/1077 - Train Accuracy: 0.7305, Validation Accuracy: 0.7266, Loss: 0.3935
# Epoch   3 Batch  306/1077 - Train Accuracy: 0.7481, Validation Accuracy: 0.7312, Loss: 0.3894
# Epoch   3 Batch  357/1077 - Train Accuracy: 0.7329, Validation Accuracy: 0.7301, Loss: 0.3850
# Epoch   3 Batch  408/1077 - Train Accuracy: 0.7152, Validation Accuracy: 0.7344, Loss: 0.3970
# Epoch   3 Batch  459/1077 - Train Accuracy: 0.7370, Validation Accuracy: 0.7337, Loss: 0.3669
# Epoch   3 Batch  510/1077 - Train Accuracy: 0.7531, Validation Accuracy: 0.7404, Loss: 0.3668
# Epoch   3 Batch  561/1077 - Train Accuracy: 0.7638, Validation Accuracy: 0.7390, Loss: 0.3520
# Epoch   3 Batch  612/1077 - Train Accuracy: 0.7504, Validation Accuracy: 0.7461, Loss: 0.3530
# Epoch   3 Batch  663/1077 - Train Accuracy: 0.7250, Validation Accuracy: 0.7457, Loss: 0.3353
# Epoch   3 Batch  714/1077 - Train Accuracy: 0.7798, Validation Accuracy: 0.7656, Loss: 0.3447
# Epoch   3 Batch  765/1077 - Train Accuracy: 0.7930, Validation Accuracy: 0.7756, Loss: 0.3276
# Epoch   3 Batch  816/1077 - Train Accuracy: 0.8199, Validation Accuracy: 0.7614, Loss: 0.3615
# Epoch   3 Batch  867/1077 - Train Accuracy: 0.7383, Validation Accuracy: 0.7599, Loss: 0.3677
# Epoch   3 Batch  918/1077 - Train Accuracy: 0.7883, Validation Accuracy: 0.7692, Loss: 0.3148
# Epoch   3 Batch  969/1077 - Train Accuracy: 0.7891, Validation Accuracy: 0.7663, Loss: 0.3332
# Epoch   3 Batch 1020/1077 - Train Accuracy: 0.7742, Validation Accuracy: 0.7784, Loss: 0.3148
# Epoch   3 Batch 1071/1077 - Train Accuracy: 0.7789, Validation Accuracy: 0.7592, Loss: 0.3107
# Epoch   4 Batch   51/1077 - Train Accuracy: 0.7730, Validation Accuracy: 0.7720, Loss: 0.3113
# Epoch   4 Batch  102/1077 - Train Accuracy: 0.7906, Validation Accuracy: 0.7710, Loss: 0.2983
# Epoch   4 Batch  153/1077 - Train Accuracy: 0.7727, Validation Accuracy: 0.7827, Loss: 0.3311
# Epoch   4 Batch  204/1077 - Train Accuracy: 0.7918, Validation Accuracy: 0.7795, Loss: 0.3238
# Epoch   4 Batch  255/1077 - Train Accuracy: 0.8039, Validation Accuracy: 0.7823, Loss: 0.2946
# Epoch   4 Batch  306/1077 - Train Accuracy: 0.8225, Validation Accuracy: 0.7901, Loss: 0.2913
# Epoch   4 Batch  357/1077 - Train Accuracy: 0.8185, Validation Accuracy: 0.8089, Loss: 0.2881
# Epoch   4 Batch  408/1077 - Train Accuracy: 0.7957, Validation Accuracy: 0.8050, Loss: 0.2895
# Epoch   4 Batch  459/1077 - Train Accuracy: 0.8274, Validation Accuracy: 0.8207, Loss: 0.2602
# Epoch   4 Batch  510/1077 - Train Accuracy: 0.8070, Validation Accuracy: 0.7969, Loss: 0.2759
# Epoch   4 Batch  561/1077 - Train Accuracy: 0.8307, Validation Accuracy: 0.7955, Loss: 0.2543
# Epoch   4 Batch  612/1077 - Train Accuracy: 0.8352, Validation Accuracy: 0.8029, Loss: 0.2606
# Epoch   4 Batch  663/1077 - Train Accuracy: 0.8332, Validation Accuracy: 0.8100, Loss: 0.2417
# Epoch   4 Batch  714/1077 - Train Accuracy: 0.8635, Validation Accuracy: 0.8267, Loss: 0.2458
# Epoch   4 Batch  765/1077 - Train Accuracy: 0.8371, Validation Accuracy: 0.8388, Loss: 0.2415
# Epoch   4 Batch  816/1077 - Train Accuracy: 0.8532, Validation Accuracy: 0.8395, Loss: 0.2710
# Epoch   4 Batch  867/1077 - Train Accuracy: 0.8180, Validation Accuracy: 0.8406, Loss: 0.2867
# Epoch   4 Batch  918/1077 - Train Accuracy: 0.8553, Validation Accuracy: 0.8388, Loss: 0.2275
# Epoch   4 Batch  969/1077 - Train Accuracy: 0.8393, Validation Accuracy: 0.8345, Loss: 0.2479
# Epoch   4 Batch 1020/1077 - Train Accuracy: 0.8426, Validation Accuracy: 0.8288, Loss: 0.2211
# Epoch   4 Batch 1071/1077 - Train Accuracy: 0.8344, Validation Accuracy: 0.8434, Loss: 0.2292
# Epoch   5 Batch   51/1077 - Train Accuracy: 0.8187, Validation Accuracy: 0.8391, Loss: 0.2313
# Epoch   5 Batch  102/1077 - Train Accuracy: 0.8375, Validation Accuracy: 0.8512, Loss: 0.2218
# Epoch   5 Batch  153/1077 - Train Accuracy: 0.8477, Validation Accuracy: 0.8370, Loss: 0.2414
# Epoch   5 Batch  204/1077 - Train Accuracy: 0.8313, Validation Accuracy: 0.8466, Loss: 0.2438
# Epoch   5 Batch  255/1077 - Train Accuracy: 0.8586, Validation Accuracy: 0.8430, Loss: 0.2242
# Epoch   5 Batch  306/1077 - Train Accuracy: 0.8698, Validation Accuracy: 0.8519, Loss: 0.2147
# Epoch   5 Batch  357/1077 - Train Accuracy: 0.8382, Validation Accuracy: 0.8320, Loss: 0.2118
# Epoch   5 Batch  408/1077 - Train Accuracy: 0.8492, Validation Accuracy: 0.8462, Loss: 0.2125
# Epoch   5 Batch  459/1077 - Train Accuracy: 0.8393, Validation Accuracy: 0.8480, Loss: 0.2006
# Epoch   5 Batch  510/1077 - Train Accuracy: 0.8359, Validation Accuracy: 0.8342, Loss: 0.2067
# Epoch   5 Batch  561/1077 - Train Accuracy: 0.8605, Validation Accuracy: 0.8327, Loss: 0.1974
# Epoch   5 Batch  612/1077 - Train Accuracy: 0.8810, Validation Accuracy: 0.8523, Loss: 0.1956
# Epoch   5 Batch  663/1077 - Train Accuracy: 0.8734, Validation Accuracy: 0.8569, Loss: 0.1808
# Epoch   5 Batch  714/1077 - Train Accuracy: 0.8891, Validation Accuracy: 0.8597, Loss: 0.1912
# Epoch   5 Batch  765/1077 - Train Accuracy: 0.8598, Validation Accuracy: 0.8597, Loss: 0.1978
# Epoch   5 Batch  816/1077 - Train Accuracy: 0.8614, Validation Accuracy: 0.8580, Loss: 0.2055
# Epoch   5 Batch  867/1077 - Train Accuracy: 0.8359, Validation Accuracy: 0.8491, Loss: 0.2259
# Epoch   5 Batch  918/1077 - Train Accuracy: 0.8690, Validation Accuracy: 0.8548, Loss: 0.1794
# Epoch   5 Batch  969/1077 - Train Accuracy: 0.8464, Validation Accuracy: 0.8452, Loss: 0.2043
# Epoch   5 Batch 1020/1077 - Train Accuracy: 0.8844, Validation Accuracy: 0.8626, Loss: 0.1737
# Epoch   5 Batch 1071/1077 - Train Accuracy: 0.8645, Validation Accuracy: 0.8583, Loss: 0.1747
# Epoch   6 Batch   51/1077 - Train Accuracy: 0.8625, Validation Accuracy: 0.8548, Loss: 0.1800
# Epoch   6 Batch  102/1077 - Train Accuracy: 0.8715, Validation Accuracy: 0.8700, Loss: 0.1798
# Epoch   6 Batch  153/1077 - Train Accuracy: 0.8531, Validation Accuracy: 0.8572, Loss: 0.1930
# Epoch   6 Batch  204/1077 - Train Accuracy: 0.8520, Validation Accuracy: 0.8565, Loss: 0.1961
# Epoch   6 Batch  255/1077 - Train Accuracy: 0.8828, Validation Accuracy: 0.8668, Loss: 0.1688
# Epoch   6 Batch  306/1077 - Train Accuracy: 0.8862, Validation Accuracy: 0.8587, Loss: 0.1708
# Epoch   6 Batch  357/1077 - Train Accuracy: 0.8601, Validation Accuracy: 0.8494, Loss: 0.1668
# Epoch   6 Batch  408/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8597, Loss: 0.1694
# Epoch   6 Batch  459/1077 - Train Accuracy: 0.8847, Validation Accuracy: 0.8487, Loss: 0.1642
# Epoch   6 Batch  510/1077 - Train Accuracy: 0.8598, Validation Accuracy: 0.8622, Loss: 0.1594
# Epoch   6 Batch  561/1077 - Train Accuracy: 0.8802, Validation Accuracy: 0.8597, Loss: 0.1520
# Epoch   6 Batch  612/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.8661, Loss: 0.1528
# Epoch   6 Batch  663/1077 - Train Accuracy: 0.8945, Validation Accuracy: 0.8693, Loss: 0.1473
# Epoch   6 Batch  714/1077 - Train Accuracy: 0.9033, Validation Accuracy: 0.8594, Loss: 0.1524
# Epoch   6 Batch  765/1077 - Train Accuracy: 0.8785, Validation Accuracy: 0.8580, Loss: 0.1574
# Epoch   6 Batch  816/1077 - Train Accuracy: 0.9120, Validation Accuracy: 0.8622, Loss: 0.1718
# Epoch   6 Batch  867/1077 - Train Accuracy: 0.8629, Validation Accuracy: 0.8480, Loss: 0.1901
# Epoch   6 Batch  918/1077 - Train Accuracy: 0.8791, Validation Accuracy: 0.8558, Loss: 0.1445
# Epoch   6 Batch  969/1077 - Train Accuracy: 0.8672, Validation Accuracy: 0.8693, Loss: 0.1700
# Epoch   6 Batch 1020/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.8580, Loss: 0.1412
# Epoch   6 Batch 1071/1077 - Train Accuracy: 0.8859, Validation Accuracy: 0.8736, Loss: 0.1394
# Epoch   7 Batch   51/1077 - Train Accuracy: 0.8754, Validation Accuracy: 0.8690, Loss: 0.1377
# Epoch   7 Batch  102/1077 - Train Accuracy: 0.8926, Validation Accuracy: 0.8764, Loss: 0.1383
# Epoch   7 Batch  153/1077 - Train Accuracy: 0.8727, Validation Accuracy: 0.8643, Loss: 0.1529
# Epoch   7 Batch  204/1077 - Train Accuracy: 0.8590, Validation Accuracy: 0.8793, Loss: 0.1609
# Epoch   7 Batch  255/1077 - Train Accuracy: 0.9000, Validation Accuracy: 0.8778, Loss: 0.1351
# Epoch   7 Batch  306/1077 - Train Accuracy: 0.8958, Validation Accuracy: 0.8746, Loss: 0.1383
# Epoch   7 Batch  357/1077 - Train Accuracy: 0.8821, Validation Accuracy: 0.8675, Loss: 0.1400
# Epoch   7 Batch  408/1077 - Train Accuracy: 0.8863, Validation Accuracy: 0.8842, Loss: 0.1377
# Epoch   7 Batch  459/1077 - Train Accuracy: 0.9085, Validation Accuracy: 0.8807, Loss: 0.1307
# Epoch   7 Batch  510/1077 - Train Accuracy: 0.8770, Validation Accuracy: 0.8878, Loss: 0.1250
# Epoch   7 Batch  561/1077 - Train Accuracy: 0.8981, Validation Accuracy: 0.8920, Loss: 0.1222
# Epoch   7 Batch  612/1077 - Train Accuracy: 0.9312, Validation Accuracy: 0.8910, Loss: 0.1207
# Epoch   7 Batch  663/1077 - Train Accuracy: 0.9168, Validation Accuracy: 0.9006, Loss: 0.1114
# Epoch   7 Batch  714/1077 - Train Accuracy: 0.9096, Validation Accuracy: 0.8899, Loss: 0.1232
# Epoch   7 Batch  765/1077 - Train Accuracy: 0.8984, Validation Accuracy: 0.8793, Loss: 0.1280
# Epoch   7 Batch  816/1077 - Train Accuracy: 0.9248, Validation Accuracy: 0.9020, Loss: 0.1331
# Epoch   7 Batch  867/1077 - Train Accuracy: 0.9012, Validation Accuracy: 0.8803, Loss: 0.1974
# Epoch   7 Batch  918/1077 - Train Accuracy: 0.8929, Validation Accuracy: 0.8974, Loss: 0.1174
# Epoch   7 Batch  969/1077 - Train Accuracy: 0.8780, Validation Accuracy: 0.8917, Loss: 0.1315
# Epoch   7 Batch 1020/1077 - Train Accuracy: 0.9398, Validation Accuracy: 0.8853, Loss: 0.1046
# Epoch   7 Batch 1071/1077 - Train Accuracy: 0.9082, Validation Accuracy: 0.8924, Loss: 0.1064
# Epoch   8 Batch   51/1077 - Train Accuracy: 0.8934, Validation Accuracy: 0.8888, Loss: 0.1138
# Epoch   8 Batch  102/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.8913, Loss: 0.1155
# Epoch   8 Batch  153/1077 - Train Accuracy: 0.8910, Validation Accuracy: 0.8999, Loss: 0.1214
# Epoch   8 Batch  204/1077 - Train Accuracy: 0.8812, Validation Accuracy: 0.9013, Loss: 0.1309
# Epoch   8 Batch  255/1077 - Train Accuracy: 0.9078, Validation Accuracy: 0.8952, Loss: 0.1026
# Epoch   8 Batch  306/1077 - Train Accuracy: 0.9003, Validation Accuracy: 0.9109, Loss: 0.1143
# Epoch   8 Batch  357/1077 - Train Accuracy: 0.8754, Validation Accuracy: 0.8853, Loss: 0.1017
# Epoch   8 Batch  408/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.8899, Loss: 0.1200
# Epoch   8 Batch  459/1077 - Train Accuracy: 0.9156, Validation Accuracy: 0.9070, Loss: 0.0967
# Epoch   8 Batch  510/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8963, Loss: 0.1005
# Epoch   8 Batch  561/1077 - Train Accuracy: 0.9141, Validation Accuracy: 0.8974, Loss: 0.0927
# Epoch   8 Batch  612/1077 - Train Accuracy: 0.9401, Validation Accuracy: 0.8967, Loss: 0.0880
# Epoch   8 Batch  663/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.9148, Loss: 0.0788
# Epoch   8 Batch  714/1077 - Train Accuracy: 0.9196, Validation Accuracy: 0.8977, Loss: 0.0975
# Epoch   8 Batch  765/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.8991, Loss: 0.0933
# Epoch   8 Batch  816/1077 - Train Accuracy: 0.9494, Validation Accuracy: 0.8970, Loss: 0.1025
# Epoch   8 Batch  867/1077 - Train Accuracy: 0.8957, Validation Accuracy: 0.8999, Loss: 0.1282
# Epoch   8 Batch  918/1077 - Train Accuracy: 0.9033, Validation Accuracy: 0.8945, Loss: 0.0907
# Epoch   8 Batch  969/1077 - Train Accuracy: 0.8895, Validation Accuracy: 0.9023, Loss: 0.1039
# Epoch   8 Batch 1020/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.9027, Loss: 0.0762
# Epoch   8 Batch 1071/1077 - Train Accuracy: 0.9250, Validation Accuracy: 0.8984, Loss: 0.0850
# Epoch   9 Batch   51/1077 - Train Accuracy: 0.9039, Validation Accuracy: 0.9073, Loss: 0.0832
# Epoch   9 Batch  102/1077 - Train Accuracy: 0.9313, Validation Accuracy: 0.9031, Loss: 0.0960
# Epoch   9 Batch  153/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.9052, Loss: 0.1007
# Epoch   9 Batch  204/1077 - Train Accuracy: 0.8867, Validation Accuracy: 0.8949, Loss: 0.1073
# Epoch   9 Batch  255/1077 - Train Accuracy: 0.9191, Validation Accuracy: 0.9119, Loss: 0.0842
# Epoch   9 Batch  306/1077 - Train Accuracy: 0.9193, Validation Accuracy: 0.9066, Loss: 0.0913
# Epoch   9 Batch  357/1077 - Train Accuracy: 0.9118, Validation Accuracy: 0.8931, Loss: 0.0906
# Epoch   9 Batch  408/1077 - Train Accuracy: 0.9141, Validation Accuracy: 0.9162, Loss: 0.0898
# Epoch   9 Batch  459/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.9155, Loss: 0.0871
# Epoch   9 Batch  510/1077 - Train Accuracy: 0.9109, Validation Accuracy: 0.8981, Loss: 0.0725
# Epoch   9 Batch  561/1077 - Train Accuracy: 0.9360, Validation Accuracy: 0.9020, Loss: 0.0805
# Epoch   9 Batch  612/1077 - Train Accuracy: 0.9572, Validation Accuracy: 0.9148, Loss: 0.0711
# Epoch   9 Batch  663/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9084, Loss: 0.0645
# Epoch   9 Batch  714/1077 - Train Accuracy: 0.9156, Validation Accuracy: 0.9123, Loss: 0.0712
# Epoch   9 Batch  765/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.9244, Loss: 0.0837
# Epoch   9 Batch  816/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9158, Loss: 0.0768
# Epoch   9 Batch  867/1077 - Train Accuracy: 0.9039, Validation Accuracy: 0.9023, Loss: 0.1171
# Epoch   9 Batch  918/1077 - Train Accuracy: 0.9260, Validation Accuracy: 0.9158, Loss: 0.0735
# Epoch   9 Batch  969/1077 - Train Accuracy: 0.8951, Validation Accuracy: 0.9180, Loss: 0.0903
# Epoch   9 Batch 1020/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9126, Loss: 0.0602
# Epoch   9 Batch 1071/1077 - Train Accuracy: 0.9168, Validation Accuracy: 0.9165, Loss: 0.0724
# Epoch  10 Batch   51/1077 - Train Accuracy: 0.8949, Validation Accuracy: 0.9180, Loss: 0.0706
# Epoch  10 Batch  102/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9311, Loss: 0.0754
# Epoch  10 Batch  153/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.9201, Loss: 0.0892
# Epoch  10 Batch  204/1077 - Train Accuracy: 0.9031, Validation Accuracy: 0.9229, Loss: 0.0888
# Epoch  10 Batch  255/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.9123, Loss: 0.0602
# Epoch  10 Batch  306/1077 - Train Accuracy: 0.9185, Validation Accuracy: 0.9194, Loss: 0.0809
# Epoch  10 Batch  357/1077 - Train Accuracy: 0.9044, Validation Accuracy: 0.8888, Loss: 0.0755
# Epoch  10 Batch  408/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9247, Loss: 0.0768
# Epoch  10 Batch  459/1077 - Train Accuracy: 0.9278, Validation Accuracy: 0.9137, Loss: 0.0671
# Epoch  10 Batch  510/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.9254, Loss: 0.0680
# Epoch  10 Batch  561/1077 - Train Accuracy: 0.9267, Validation Accuracy: 0.9212, Loss: 0.0656
# Epoch  10 Batch  612/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9141, Loss: 0.0623
# Epoch  10 Batch  663/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9268, Loss: 0.0568
# Epoch  10 Batch  714/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9208, Loss: 0.0610
# Epoch  10 Batch  765/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9190, Loss: 0.0671
# Epoch  10 Batch  816/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9339, Loss: 0.0750
# Epoch  10 Batch  867/1077 - Train Accuracy: 0.9074, Validation Accuracy: 0.9208, Loss: 0.1033
# Epoch  10 Batch  918/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.9187, Loss: 0.0636
# Epoch  10 Batch  969/1077 - Train Accuracy: 0.9044, Validation Accuracy: 0.9187, Loss: 0.0771
# Epoch  10 Batch 1020/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9300, Loss: 0.0508
# Epoch  10 Batch 1071/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.9180, Loss: 0.0555
# Epoch  11 Batch   51/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9407, Loss: 0.0573
# Epoch  11 Batch  102/1077 - Train Accuracy: 0.9437, Validation Accuracy: 0.9251, Loss: 0.0639
# Epoch  11 Batch  153/1077 - Train Accuracy: 0.9250, Validation Accuracy: 0.9272, Loss: 0.0760
# Epoch  11 Batch  204/1077 - Train Accuracy: 0.9078, Validation Accuracy: 0.9332, Loss: 0.0788
# Epoch  11 Batch  255/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9286, Loss: 0.0650
# Epoch  11 Batch  306/1077 - Train Accuracy: 0.9256, Validation Accuracy: 0.9371, Loss: 0.0676
# Epoch  11 Batch  357/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.9304, Loss: 0.0643
# Epoch  11 Batch  408/1077 - Train Accuracy: 0.9473, Validation Accuracy: 0.9300, Loss: 0.0695
# Epoch  11 Batch  459/1077 - Train Accuracy: 0.9338, Validation Accuracy: 0.9180, Loss: 0.0648
# Epoch  11 Batch  510/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9400, Loss: 0.0590
# Epoch  11 Batch  561/1077 - Train Accuracy: 0.9368, Validation Accuracy: 0.9205, Loss: 0.0511
# Epoch  11 Batch  612/1077 - Train Accuracy: 0.9524, Validation Accuracy: 0.9240, Loss: 0.0491
# Epoch  11 Batch  663/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9347, Loss: 0.0568
# Epoch  11 Batch  714/1077 - Train Accuracy: 0.9334, Validation Accuracy: 0.9229, Loss: 0.0553
# Epoch  11 Batch  765/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9240, Loss: 0.0658
# Epoch  11 Batch  816/1077 - Train Accuracy: 0.9552, Validation Accuracy: 0.9293, Loss: 0.0619
# Epoch  11 Batch  867/1077 - Train Accuracy: 0.9199, Validation Accuracy: 0.9297, Loss: 0.0868
# Epoch  11 Batch  918/1077 - Train Accuracy: 0.9334, Validation Accuracy: 0.9318, Loss: 0.0573
# Epoch  11 Batch  969/1077 - Train Accuracy: 0.9115, Validation Accuracy: 0.9180, Loss: 0.0706
# Epoch  11 Batch 1020/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9286, Loss: 0.0445
# Epoch  11 Batch 1071/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9261, Loss: 0.0483
# Epoch  12 Batch   51/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.9361, Loss: 0.0558
# Epoch  12 Batch  102/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9350, Loss: 0.0575
# Epoch  12 Batch  153/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9183, Loss: 0.0654
# Epoch  12 Batch  204/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.9396, Loss: 0.0689
# Epoch  12 Batch  255/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9478, Loss: 0.0587
# Epoch  12 Batch  306/1077 - Train Accuracy: 0.9397, Validation Accuracy: 0.9361, Loss: 0.0613
# Epoch  12 Batch  357/1077 - Train Accuracy: 0.9107, Validation Accuracy: 0.9304, Loss: 0.0567
# Epoch  12 Batch  408/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9439, Loss: 0.0550
# Epoch  12 Batch  459/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9134, Loss: 0.0560
# Epoch  12 Batch  510/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9439, Loss: 0.0554
# Epoch  12 Batch  561/1077 - Train Accuracy: 0.9386, Validation Accuracy: 0.9418, Loss: 0.0511
# Epoch  12 Batch  612/1077 - Train Accuracy: 0.9643, Validation Accuracy: 0.9411, Loss: 0.0422
# Epoch  12 Batch  663/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9371, Loss: 0.0445
# Epoch  12 Batch  714/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9286, Loss: 0.0493
# Epoch  12 Batch  765/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.9386, Loss: 0.0568
# Epoch  12 Batch  816/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9442, Loss: 0.0578
# Epoch  12 Batch  867/1077 - Train Accuracy: 0.9262, Validation Accuracy: 0.9478, Loss: 0.0865
# Epoch  12 Batch  918/1077 - Train Accuracy: 0.9263, Validation Accuracy: 0.9332, Loss: 0.0537
# Epoch  12 Batch  969/1077 - Train Accuracy: 0.9029, Validation Accuracy: 0.9244, Loss: 0.0592
# Epoch  12 Batch 1020/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9371, Loss: 0.0436
# Epoch  12 Batch 1071/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.9339, Loss: 0.0443
# Epoch  13 Batch   51/1077 - Train Accuracy: 0.9227, Validation Accuracy: 0.9432, Loss: 0.0485
# Epoch  13 Batch  102/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9453, Loss: 0.0498
# Epoch  13 Batch  153/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9382, Loss: 0.0613
# Epoch  13 Batch  204/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9332, Loss: 0.0719
# Epoch  13 Batch  255/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9418, Loss: 0.0480
# Epoch  13 Batch  306/1077 - Train Accuracy: 0.9327, Validation Accuracy: 0.9251, Loss: 0.0569
# Epoch  13 Batch  357/1077 - Train Accuracy: 0.9312, Validation Accuracy: 0.9226, Loss: 0.0524
# Epoch  13 Batch  408/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9382, Loss: 0.0545
# Epoch  13 Batch  459/1077 - Train Accuracy: 0.9423, Validation Accuracy: 0.9471, Loss: 0.0496
# Epoch  13 Batch  510/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9471, Loss: 0.0422
# Epoch  13 Batch  561/1077 - Train Accuracy: 0.9397, Validation Accuracy: 0.9425, Loss: 0.0491
# Epoch  13 Batch  612/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9496, Loss: 0.0438
# Epoch  13 Batch  663/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9361, Loss: 0.0395
# Epoch  13 Batch  714/1077 - Train Accuracy: 0.9557, Validation Accuracy: 0.9325, Loss: 0.0447
# Epoch  13 Batch  765/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9442, Loss: 0.0521
# Epoch  13 Batch  816/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9411, Loss: 0.0500
# Epoch  13 Batch  867/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9457, Loss: 0.0726
# Epoch  13 Batch  918/1077 - Train Accuracy: 0.9408, Validation Accuracy: 0.9311, Loss: 0.0473
# Epoch  13 Batch  969/1077 - Train Accuracy: 0.9193, Validation Accuracy: 0.9350, Loss: 0.0534
# Epoch  13 Batch 1020/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9446, Loss: 0.0367
# Epoch  13 Batch 1071/1077 - Train Accuracy: 0.9305, Validation Accuracy: 0.9411, Loss: 0.0373
# Epoch  14 Batch   51/1077 - Train Accuracy: 0.9316, Validation Accuracy: 0.9478, Loss: 0.0461
# Epoch  14 Batch  102/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9439, Loss: 0.0492
# Epoch  14 Batch  153/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9396, Loss: 0.0617
# Epoch  14 Batch  204/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9510, Loss: 0.0598
# Epoch  14 Batch  255/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9616, Loss: 0.0348
# Epoch  14 Batch  306/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9446, Loss: 0.0536
# Epoch  14 Batch  357/1077 - Train Accuracy: 0.9427, Validation Accuracy: 0.9538, Loss: 0.0489
# Epoch  14 Batch  408/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9531, Loss: 0.0504
# Epoch  14 Batch  459/1077 - Train Accuracy: 0.9408, Validation Accuracy: 0.9339, Loss: 0.0489
# Epoch  14 Batch  510/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9325, Loss: 0.0403
# Epoch  14 Batch  561/1077 - Train Accuracy: 0.9412, Validation Accuracy: 0.9432, Loss: 0.0465
# Epoch  14 Batch  612/1077 - Train Accuracy: 0.9658, Validation Accuracy: 0.9460, Loss: 0.0414
# Epoch  14 Batch  663/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9428, Loss: 0.0369
# Epoch  14 Batch  714/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9496, Loss: 0.0470
# Epoch  14 Batch  765/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9425, Loss: 0.0492
# Epoch  14 Batch  816/1077 - Train Accuracy: 0.9683, Validation Accuracy: 0.9414, Loss: 0.0536
# Epoch  14 Batch  867/1077 - Train Accuracy: 0.9313, Validation Accuracy: 0.9478, Loss: 0.0787
# Epoch  14 Batch  918/1077 - Train Accuracy: 0.9464, Validation Accuracy: 0.9496, Loss: 0.0407
# Epoch  14 Batch  969/1077 - Train Accuracy: 0.9308, Validation Accuracy: 0.9379, Loss: 0.0564
# Epoch  14 Batch 1020/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9464, Loss: 0.0420
# Epoch  14 Batch 1071/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9471, Loss: 0.0417
# Epoch  15 Batch   51/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9442, Loss: 0.0370
# Epoch  15 Batch  102/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9478, Loss: 0.0436
# Epoch  15 Batch  153/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9439, Loss: 0.0576
# Epoch  15 Batch  204/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9535, Loss: 0.0616
# Epoch  15 Batch  255/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9581, Loss: 0.0356
# Epoch  15 Batch  306/1077 - Train Accuracy: 0.9442, Validation Accuracy: 0.9450, Loss: 0.0490
# Epoch  15 Batch  357/1077 - Train Accuracy: 0.9475, Validation Accuracy: 0.9560, Loss: 0.0458
# Epoch  15 Batch  408/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9521, Loss: 0.0465
# Epoch  15 Batch  459/1077 - Train Accuracy: 0.9505, Validation Accuracy: 0.9556, Loss: 0.0477
# Epoch  15 Batch  510/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9538, Loss: 0.0420
# Epoch  15 Batch  561/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9489, Loss: 0.0363
# Epoch  15 Batch  612/1077 - Train Accuracy: 0.9661, Validation Accuracy: 0.9418, Loss: 0.0364
# Epoch  15 Batch  663/1077 - Train Accuracy: 0.9410, Validation Accuracy: 0.9549, Loss: 0.0324
# Epoch  15 Batch  714/1077 - Train Accuracy: 0.9751, Validation Accuracy: 0.9528, Loss: 0.0384
# Epoch  15 Batch  765/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.9503, Loss: 0.0440
# Epoch  15 Batch  816/1077 - Train Accuracy: 0.9671, Validation Accuracy: 0.9521, Loss: 0.0404
# Epoch  15 Batch  867/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9542, Loss: 0.0708
# Epoch  15 Batch  918/1077 - Train Accuracy: 0.9568, Validation Accuracy: 0.9542, Loss: 0.0376
# Epoch  15 Batch  969/1077 - Train Accuracy: 0.9267, Validation Accuracy: 0.9453, Loss: 0.0524
# Epoch  15 Batch 1020/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9563, Loss: 0.0337
# Epoch  15 Batch 1071/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.9521, Loss: 0.0377
# Epoch  16 Batch   51/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.9535, Loss: 0.0446
# Epoch  16 Batch  102/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9467, Loss: 0.0382
# Epoch  16 Batch  153/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9517, Loss: 0.0517
# Epoch  16 Batch  204/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9549, Loss: 0.0577
# Epoch  16 Batch  255/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9684, Loss: 0.0433
# Epoch  16 Batch  306/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9574, Loss: 0.0516
# Epoch  16 Batch  357/1077 - Train Accuracy: 0.9487, Validation Accuracy: 0.9382, Loss: 0.0466
# Epoch  16 Batch  408/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9538, Loss: 0.0484
# Epoch  16 Batch  459/1077 - Train Accuracy: 0.9505, Validation Accuracy: 0.9577, Loss: 0.0456
# Epoch  16 Batch  510/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9581, Loss: 0.0373
# Epoch  16 Batch  561/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9428, Loss: 0.0377
# Epoch  16 Batch  612/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9567, Loss: 0.0345
# Epoch  16 Batch  663/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9513, Loss: 0.0321
# Epoch  16 Batch  714/1077 - Train Accuracy: 0.9743, Validation Accuracy: 0.9425, Loss: 0.0348
# Epoch  16 Batch  765/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9506, Loss: 0.0435
# Epoch  16 Batch  816/1077 - Train Accuracy: 0.9741, Validation Accuracy: 0.9556, Loss: 0.0374
# Epoch  16 Batch  867/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9563, Loss: 0.0699
# Epoch  16 Batch  918/1077 - Train Accuracy: 0.9572, Validation Accuracy: 0.9560, Loss: 0.0358
# Epoch  16 Batch  969/1077 - Train Accuracy: 0.9327, Validation Accuracy: 0.9421, Loss: 0.0542
# Epoch  16 Batch 1020/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9553, Loss: 0.0305
# Epoch  16 Batch 1071/1077 - Train Accuracy: 0.9398, Validation Accuracy: 0.9595, Loss: 0.0393
# Epoch  17 Batch   51/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9556, Loss: 0.0375
# Epoch  17 Batch  102/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9542, Loss: 0.0418
# Epoch  17 Batch  153/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9350, Loss: 0.0465
# Epoch  17 Batch  204/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9531, Loss: 0.0521
# Epoch  17 Batch  255/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9613, Loss: 0.0413
# Epoch  17 Batch  306/1077 - Train Accuracy: 0.9635, Validation Accuracy: 0.9478, Loss: 0.0501
# Epoch  17 Batch  357/1077 - Train Accuracy: 0.9472, Validation Accuracy: 0.9638, Loss: 0.0409
# Epoch  17 Batch  408/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9439, Loss: 0.0389
# Epoch  17 Batch  459/1077 - Train Accuracy: 0.9591, Validation Accuracy: 0.9634, Loss: 0.0419
# Epoch  17 Batch  510/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9553, Loss: 0.0365
# Epoch  17 Batch  561/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9517, Loss: 0.0326
# Epoch  17 Batch  612/1077 - Train Accuracy: 0.9710, Validation Accuracy: 0.9489, Loss: 0.0337
# Epoch  17 Batch  663/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9585, Loss: 0.0350
# Epoch  17 Batch  714/1077 - Train Accuracy: 0.9740, Validation Accuracy: 0.9513, Loss: 0.0390
# Epoch  17 Batch  765/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9531, Loss: 0.0435
# Epoch  17 Batch  816/1077 - Train Accuracy: 0.9757, Validation Accuracy: 0.9620, Loss: 0.0455
# Epoch  17 Batch  867/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.9666, Loss: 0.0673
# Epoch  17 Batch  918/1077 - Train Accuracy: 0.9528, Validation Accuracy: 0.9556, Loss: 0.0334
# Epoch  17 Batch  969/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9535, Loss: 0.0449
# Epoch  17 Batch 1020/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9549, Loss: 0.0324
# Epoch  17 Batch 1071/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9599, Loss: 0.0397
# Epoch  18 Batch   51/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9528, Loss: 0.0349
# Epoch  18 Batch  102/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9620, Loss: 0.0386
# Epoch  18 Batch  153/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9471, Loss: 0.0503
# Epoch  18 Batch  204/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9510, Loss: 0.0511
# Epoch  18 Batch  255/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.9545, Loss: 0.0332
# Epoch  18 Batch  306/1077 - Train Accuracy: 0.9420, Validation Accuracy: 0.9567, Loss: 0.0440
# Epoch  18 Batch  357/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9535, Loss: 0.0358
# Epoch  18 Batch  408/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9446, Loss: 0.0381
# Epoch  18 Batch  459/1077 - Train Accuracy: 0.9565, Validation Accuracy: 0.9467, Loss: 0.0365
# Epoch  18 Batch  510/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9528, Loss: 0.0315
# Epoch  18 Batch  561/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9435, Loss: 0.0371
# Epoch  18 Batch  612/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9446, Loss: 0.0334
# Epoch  18 Batch  663/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9506, Loss: 0.0325
# Epoch  18 Batch  714/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9531, Loss: 0.0382
# Epoch  18 Batch  765/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9482, Loss: 0.0443
# Epoch  18 Batch  816/1077 - Train Accuracy: 0.9737, Validation Accuracy: 0.9659, Loss: 0.0402
# Epoch  18 Batch  867/1077 - Train Accuracy: 0.9262, Validation Accuracy: 0.9556, Loss: 0.0646
# Epoch  18 Batch  918/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9496, Loss: 0.0334
# Epoch  18 Batch  969/1077 - Train Accuracy: 0.9330, Validation Accuracy: 0.9563, Loss: 0.0432
# Epoch  18 Batch 1020/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9567, Loss: 0.0261
# Epoch  18 Batch 1071/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9624, Loss: 0.0339
# Epoch  19 Batch   51/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9510, Loss: 0.0328
# Epoch  19 Batch  102/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9556, Loss: 0.0341
# Epoch  19 Batch  153/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9606, Loss: 0.0423
# Epoch  19 Batch  204/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9574, Loss: 0.0498
# Epoch  19 Batch  255/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9570, Loss: 0.0322
# Epoch  19 Batch  306/1077 - Train Accuracy: 0.9524, Validation Accuracy: 0.9435, Loss: 0.0467
# Epoch  19 Batch  357/1077 - Train Accuracy: 0.9420, Validation Accuracy: 0.9460, Loss: 0.0363
# Epoch  19 Batch  408/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9577, Loss: 0.0354
# Epoch  19 Batch  459/1077 - Train Accuracy: 0.9561, Validation Accuracy: 0.9577, Loss: 0.0343
# Epoch  19 Batch  510/1077 - Train Accuracy: 0.9637, Validation Accuracy: 0.9563, Loss: 0.0324
# Epoch  19 Batch  561/1077 - Train Accuracy: 0.9587, Validation Accuracy: 0.9517, Loss: 0.0356
# Epoch  19 Batch  612/1077 - Train Accuracy: 0.9717, Validation Accuracy: 0.9492, Loss: 0.0290
# Epoch  19 Batch  663/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9545, Loss: 0.0282
# Epoch  19 Batch  714/1077 - Train Accuracy: 0.9736, Validation Accuracy: 0.9549, Loss: 0.0424
# Epoch  19 Batch  765/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.9460, Loss: 0.0438
# Epoch  19 Batch  816/1077 - Train Accuracy: 0.9741, Validation Accuracy: 0.9460, Loss: 0.0342
# Epoch  19 Batch  867/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9556, Loss: 0.0664
# Epoch  19 Batch  918/1077 - Train Accuracy: 0.9665, Validation Accuracy: 0.9467, Loss: 0.0328
# Epoch  19 Batch  969/1077 - Train Accuracy: 0.9364, Validation Accuracy: 0.9585, Loss: 0.0383
# Epoch  19 Batch 1020/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9482, Loss: 0.0331
# Epoch  19 Batch 1071/1077 - Train Accuracy: 0.9543, Validation Accuracy: 0.9652, Loss: 0.0298
# Epoch  20 Batch   51/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9560, Loss: 0.0333
# Epoch  20 Batch  102/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9524, Loss: 0.0324
# Epoch  20 Batch  153/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9567, Loss: 0.0427
# Epoch  20 Batch  204/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9503, Loss: 0.0531
# Epoch  20 Batch  255/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9567, Loss: 0.0327
# Epoch  20 Batch  306/1077 - Train Accuracy: 0.9546, Validation Accuracy: 0.9680, Loss: 0.0453
# Epoch  20 Batch  357/1077 - Train Accuracy: 0.9554, Validation Accuracy: 0.9616, Loss: 0.0339
# Epoch  20 Batch  408/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9592, Loss: 0.0342
# Epoch  20 Batch  459/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9656, Loss: 0.0337
# Epoch  20 Batch  510/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9606, Loss: 0.0298
# Epoch  20 Batch  561/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9485, Loss: 0.0307
# Epoch  20 Batch  612/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9545, Loss: 0.0284
# Epoch  20 Batch  663/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9524, Loss: 0.0285
# Epoch  20 Batch  714/1077 - Train Accuracy: 0.9769, Validation Accuracy: 0.9567, Loss: 0.0349
# Epoch  20 Batch  765/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.9485, Loss: 0.0369
# Epoch  20 Batch  816/1077 - Train Accuracy: 0.9725, Validation Accuracy: 0.9602, Loss: 0.0356
# Epoch  20 Batch  867/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9585, Loss: 0.0575
# Epoch  20 Batch  918/1077 - Train Accuracy: 0.9643, Validation Accuracy: 0.9542, Loss: 0.0288
# Epoch  20 Batch  969/1077 - Train Accuracy: 0.9386, Validation Accuracy: 0.9588, Loss: 0.0433
# Epoch  20 Batch 1020/1077 - Train Accuracy: 0.9801, Validation Accuracy: 0.9549, Loss: 0.0248
# Epoch  20 Batch 1071/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9606, Loss: 0.0317
# Epoch  21 Batch   51/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9688, Loss: 0.0383
# Epoch  21 Batch  102/1077 - Train Accuracy: 0.9805, Validation Accuracy: 0.9638, Loss: 0.0310
# Epoch  21 Batch  153/1077 - Train Accuracy: 0.9410, Validation Accuracy: 0.9567, Loss: 0.0378
# Epoch  21 Batch  204/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9553, Loss: 0.0529
# Epoch  21 Batch  255/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9528, Loss: 0.0347
# Epoch  21 Batch  306/1077 - Train Accuracy: 0.9647, Validation Accuracy: 0.9609, Loss: 0.0405
# Epoch  21 Batch  357/1077 - Train Accuracy: 0.9650, Validation Accuracy: 0.9585, Loss: 0.0332
# Epoch  21 Batch  408/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9489, Loss: 0.0305
# Epoch  21 Batch  459/1077 - Train Accuracy: 0.9565, Validation Accuracy: 0.9659, Loss: 0.0374
# Epoch  21 Batch  510/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9556, Loss: 0.0291
# Epoch  21 Batch  561/1077 - Train Accuracy: 0.9669, Validation Accuracy: 0.9553, Loss: 0.0318
# Epoch  21 Batch  612/1077 - Train Accuracy: 0.9661, Validation Accuracy: 0.9638, Loss: 0.0305
# Epoch  21 Batch  663/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9613, Loss: 0.0285
# Epoch  21 Batch  714/1077 - Train Accuracy: 0.9769, Validation Accuracy: 0.9535, Loss: 0.0436
# Epoch  21 Batch  765/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9478, Loss: 0.0402
# Epoch  21 Batch  816/1077 - Train Accuracy: 0.9704, Validation Accuracy: 0.9592, Loss: 0.0319
# Epoch  21 Batch  867/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9496, Loss: 0.0562
# Epoch  21 Batch  918/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9521, Loss: 0.0320
# Epoch  21 Batch  969/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9538, Loss: 0.0352
# Epoch  21 Batch 1020/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9553, Loss: 0.0269
# Epoch  21 Batch 1071/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9641, Loss: 0.0287
# Epoch  22 Batch   51/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9585, Loss: 0.0327
# Epoch  22 Batch  102/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9606, Loss: 0.0348
# Epoch  22 Batch  153/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9616, Loss: 0.0356
# Epoch  22 Batch  204/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9553, Loss: 0.0462
# Epoch  22 Batch  255/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9567, Loss: 0.0315
# Epoch  22 Batch  306/1077 - Train Accuracy: 0.9665, Validation Accuracy: 0.9599, Loss: 0.0376
# Epoch  22 Batch  357/1077 - Train Accuracy: 0.9561, Validation Accuracy: 0.9538, Loss: 0.0336
# Epoch  22 Batch  408/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9585, Loss: 0.0366
# Epoch  22 Batch  459/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9563, Loss: 0.0300
# Epoch  22 Batch  510/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9588, Loss: 0.0296
# Epoch  22 Batch  561/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9517, Loss: 0.0279
# Epoch  22 Batch  612/1077 - Train Accuracy: 0.9647, Validation Accuracy: 0.9563, Loss: 0.0279
# Epoch  22 Batch  663/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9595, Loss: 0.0252
# Epoch  22 Batch  714/1077 - Train Accuracy: 0.9740, Validation Accuracy: 0.9581, Loss: 0.0276
# Epoch  22 Batch  765/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9482, Loss: 0.0410
# Epoch  22 Batch  816/1077 - Train Accuracy: 0.9782, Validation Accuracy: 0.9634, Loss: 0.0313
# Epoch  22 Batch  867/1077 - Train Accuracy: 0.9410, Validation Accuracy: 0.9656, Loss: 0.0700
# Epoch  22 Batch  918/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9545, Loss: 0.0250
# Epoch  22 Batch  969/1077 - Train Accuracy: 0.9386, Validation Accuracy: 0.9663, Loss: 0.0376
# Epoch  22 Batch 1020/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9648, Loss: 0.0216
# Epoch  22 Batch 1071/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9602, Loss: 0.0319
# Epoch  23 Batch   51/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9641, Loss: 0.0268
# Epoch  23 Batch  102/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9588, Loss: 0.0251
# Epoch  23 Batch  153/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9631, Loss: 0.0427
# Epoch  23 Batch  204/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9499, Loss: 0.0473
# Epoch  23 Batch  255/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9581, Loss: 0.0311
# Epoch  23 Batch  306/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9609, Loss: 0.0435
# Epoch  23 Batch  357/1077 - Train Accuracy: 0.9557, Validation Accuracy: 0.9521, Loss: 0.0379
# Epoch  23 Batch  408/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9503, Loss: 0.0307
# Epoch  23 Batch  459/1077 - Train Accuracy: 0.9661, Validation Accuracy: 0.9684, Loss: 0.0345
# Epoch  23 Batch  510/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9581, Loss: 0.0322
# Epoch  23 Batch  561/1077 - Train Accuracy: 0.9665, Validation Accuracy: 0.9528, Loss: 0.0276
# Epoch  23 Batch  612/1077 - Train Accuracy: 0.9740, Validation Accuracy: 0.9599, Loss: 0.0248
# Epoch  23 Batch  663/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9553, Loss: 0.0271
# Epoch  23 Batch  714/1077 - Train Accuracy: 0.9814, Validation Accuracy: 0.9631, Loss: 0.0417
# Epoch  23 Batch  765/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.9439, Loss: 0.0366
# Epoch  23 Batch  816/1077 - Train Accuracy: 0.9782, Validation Accuracy: 0.9641, Loss: 0.0254
# Epoch  23 Batch  867/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9613, Loss: 0.0618
# Epoch  23 Batch  918/1077 - Train Accuracy: 0.9743, Validation Accuracy: 0.9634, Loss: 0.0231
# Epoch  23 Batch  969/1077 - Train Accuracy: 0.9446, Validation Accuracy: 0.9592, Loss: 0.0335
# Epoch  23 Batch 1020/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9485, Loss: 0.0292
# Epoch  23 Batch 1071/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9688, Loss: 0.0252
# Epoch  24 Batch   51/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9613, Loss: 0.0343
# Epoch  24 Batch  102/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9634, Loss: 0.0294
# Epoch  24 Batch  153/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9641, Loss: 0.0371
# Epoch  24 Batch  204/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9631, Loss: 0.0495
# Epoch  24 Batch  255/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9659, Loss: 0.0298
# Epoch  24 Batch  306/1077 - Train Accuracy: 0.9673, Validation Accuracy: 0.9659, Loss: 0.0424
# Epoch  24 Batch  357/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9616, Loss: 0.0262
# Epoch  24 Batch  408/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9592, Loss: 0.0303
# Epoch  24 Batch  459/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9648, Loss: 0.0359
# Epoch  24 Batch  510/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9638, Loss: 0.0267
# Epoch  24 Batch  561/1077 - Train Accuracy: 0.9624, Validation Accuracy: 0.9560, Loss: 0.0252
# Epoch  24 Batch  612/1077 - Train Accuracy: 0.9721, Validation Accuracy: 0.9677, Loss: 0.0249
# Epoch  24 Batch  663/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9656, Loss: 0.0270
# Epoch  24 Batch  714/1077 - Train Accuracy: 0.9784, Validation Accuracy: 0.9634, Loss: 0.0357
# Epoch  24 Batch  765/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.9503, Loss: 0.0377
# Epoch  24 Batch  816/1077 - Train Accuracy: 0.9782, Validation Accuracy: 0.9631, Loss: 0.0322
# Epoch  24 Batch  867/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9659, Loss: 0.0567
# Epoch  24 Batch  918/1077 - Train Accuracy: 0.9728, Validation Accuracy: 0.9517, Loss: 0.0256
# Epoch  24 Batch  969/1077 - Train Accuracy: 0.9408, Validation Accuracy: 0.9659, Loss: 0.0292
# Epoch  24 Batch 1020/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9549, Loss: 0.0320
# Epoch  24 Batch 1071/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9656, Loss: 0.0249
# Epoch  25 Batch   51/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9691, Loss: 0.0265
# Epoch  25 Batch  102/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9588, Loss: 0.0266
# Epoch  25 Batch  153/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9606, Loss: 0.0400
# Epoch  25 Batch  204/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9570, Loss: 0.0462
# Epoch  25 Batch  255/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9684, Loss: 0.0273
# Epoch  25 Batch  306/1077 - Train Accuracy: 0.9673, Validation Accuracy: 0.9634, Loss: 0.0372
# Epoch  25 Batch  357/1077 - Train Accuracy: 0.9632, Validation Accuracy: 0.9620, Loss: 0.0313
# Epoch  25 Batch  408/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9652, Loss: 0.0301
# Epoch  25 Batch  459/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9702, Loss: 0.0292
# Epoch  25 Batch  510/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9684, Loss: 0.0255
# Epoch  25 Batch  561/1077 - Train Accuracy: 0.9635, Validation Accuracy: 0.9656, Loss: 0.0233
# Epoch  25 Batch  612/1077 - Train Accuracy: 0.9661, Validation Accuracy: 0.9613, Loss: 0.0255
# Epoch  25 Batch  663/1077 - Train Accuracy: 0.9637, Validation Accuracy: 0.9602, Loss: 0.0277
# Epoch  25 Batch  714/1077 - Train Accuracy: 0.9866, Validation Accuracy: 0.9709, Loss: 0.0251
# Epoch  25 Batch  765/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9659, Loss: 0.0334
# Epoch  25 Batch  816/1077 - Train Accuracy: 0.9782, Validation Accuracy: 0.9588, Loss: 0.0317
# Epoch  25 Batch  867/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9712, Loss: 0.0602
# Epoch  25 Batch  918/1077 - Train Accuracy: 0.9803, Validation Accuracy: 0.9659, Loss: 0.0237
# Epoch  25 Batch  969/1077 - Train Accuracy: 0.9416, Validation Accuracy: 0.9659, Loss: 0.0303
# Epoch  25 Batch 1020/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9670, Loss: 0.0219
# Epoch  25 Batch 1071/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9723, Loss: 0.0276
# Epoch  26 Batch   51/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9631, Loss: 0.0265
# Epoch  26 Batch  102/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9656, Loss: 0.0261
# Epoch  26 Batch  153/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9521, Loss: 0.0311
# Epoch  26 Batch  204/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9553, Loss: 0.0429
# Epoch  26 Batch  255/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9719, Loss: 0.0302
# Epoch  26 Batch  306/1077 - Train Accuracy: 0.9647, Validation Accuracy: 0.9659, Loss: 0.0347
# Epoch  26 Batch  357/1077 - Train Accuracy: 0.9505, Validation Accuracy: 0.9677, Loss: 0.0345
# Epoch  26 Batch  408/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9606, Loss: 0.0295
# Epoch  26 Batch  459/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9545, Loss: 0.0300
# Epoch  26 Batch  510/1077 - Train Accuracy: 0.9707, Validation Accuracy: 0.9641, Loss: 0.0287
# Epoch  26 Batch  561/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9592, Loss: 0.0244
# Epoch  26 Batch  612/1077 - Train Accuracy: 0.9769, Validation Accuracy: 0.9730, Loss: 0.0251
# Epoch  26 Batch  663/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9652, Loss: 0.0212
# Epoch  26 Batch  714/1077 - Train Accuracy: 0.9825, Validation Accuracy: 0.9606, Loss: 0.0349
# Epoch  26 Batch  765/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9613, Loss: 0.0350
# Epoch  26 Batch  816/1077 - Train Accuracy: 0.9729, Validation Accuracy: 0.9638, Loss: 0.0336
# Epoch  26 Batch  867/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9666, Loss: 0.0608
# Epoch  26 Batch  918/1077 - Train Accuracy: 0.9673, Validation Accuracy: 0.9670, Loss: 0.0221
# Epoch  26 Batch  969/1077 - Train Accuracy: 0.9435, Validation Accuracy: 0.9723, Loss: 0.0294
# Epoch  26 Batch 1020/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9648, Loss: 0.0292
# Epoch  26 Batch 1071/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.9695, Loss: 0.0281
# Epoch  27 Batch   51/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9677, Loss: 0.0297
# Epoch  27 Batch  102/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9723, Loss: 0.0310
# Epoch  27 Batch  153/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9673, Loss: 0.0323
# Epoch  27 Batch  204/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9638, Loss: 0.0446
# Epoch  27 Batch  255/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9656, Loss: 0.0249
# Epoch  27 Batch  306/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9663, Loss: 0.0326
# Epoch  27 Batch  357/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9719, Loss: 0.0310
# Epoch  27 Batch  408/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9542, Loss: 0.0289
# Epoch  27 Batch  459/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9585, Loss: 0.0322
# Epoch  27 Batch  510/1077 - Train Accuracy: 0.9707, Validation Accuracy: 0.9659, Loss: 0.0256
# Epoch  27 Batch  561/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9684, Loss: 0.0206
# Epoch  27 Batch  612/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9759, Loss: 0.0190
# Epoch  27 Batch  663/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9609, Loss: 0.0209
# Epoch  27 Batch  714/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9638, Loss: 0.0209
# Epoch  27 Batch  765/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9709, Loss: 0.0329
# Epoch  27 Batch  816/1077 - Train Accuracy: 0.9725, Validation Accuracy: 0.9638, Loss: 0.0317
# Epoch  27 Batch  867/1077 - Train Accuracy: 0.9437, Validation Accuracy: 0.9727, Loss: 0.0534
# Epoch  27 Batch  918/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9670, Loss: 0.0297
# Epoch  27 Batch  969/1077 - Train Accuracy: 0.9572, Validation Accuracy: 0.9762, Loss: 0.0340
# Epoch  27 Batch 1020/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9606, Loss: 0.0230
# Epoch  27 Batch 1071/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9677, Loss: 0.0279
# Epoch  28 Batch   51/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9712, Loss: 0.0296
# Epoch  28 Batch  102/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9659, Loss: 0.0236
# Epoch  28 Batch  153/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9709, Loss: 0.0344
# Epoch  28 Batch  204/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9652, Loss: 0.0414
# Epoch  28 Batch  255/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9641, Loss: 0.0246
# Epoch  28 Batch  306/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9659, Loss: 0.0324
# Epoch  28 Batch  357/1077 - Train Accuracy: 0.9587, Validation Accuracy: 0.9666, Loss: 0.0299
# Epoch  28 Batch  408/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9709, Loss: 0.0270
# Epoch  28 Batch  459/1077 - Train Accuracy: 0.9624, Validation Accuracy: 0.9631, Loss: 0.0293
# Epoch  28 Batch  510/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9723, Loss: 0.0274
# Epoch  28 Batch  561/1077 - Train Accuracy: 0.9717, Validation Accuracy: 0.9684, Loss: 0.0238
# Epoch  28 Batch  612/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9727, Loss: 0.0205
# Epoch  28 Batch  663/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9705, Loss: 0.0222
# Epoch  28 Batch  714/1077 - Train Accuracy: 0.9862, Validation Accuracy: 0.9673, Loss: 0.0249
# Epoch  28 Batch  765/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9624, Loss: 0.0338
# Epoch  28 Batch  816/1077 - Train Accuracy: 0.9745, Validation Accuracy: 0.9645, Loss: 0.0293
# Epoch  28 Batch  867/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9712, Loss: 0.0597
# Epoch  28 Batch  918/1077 - Train Accuracy: 0.9862, Validation Accuracy: 0.9727, Loss: 0.0208
# Epoch  28 Batch  969/1077 - Train Accuracy: 0.9550, Validation Accuracy: 0.9684, Loss: 0.0295
# Epoch  28 Batch 1020/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9616, Loss: 0.0197
# Epoch  28 Batch 1071/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9723, Loss: 0.0298
# Epoch  29 Batch   51/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9705, Loss: 0.0283
# Epoch  29 Batch  102/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9712, Loss: 0.0271
# Epoch  29 Batch  153/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9673, Loss: 0.0327
# Epoch  29 Batch  204/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9734, Loss: 0.0435
# Epoch  29 Batch  255/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9709, Loss: 0.0216
# Epoch  29 Batch  306/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9709, Loss: 0.0305
# Epoch  29 Batch  357/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9734, Loss: 0.0268
# Epoch  29 Batch  408/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9670, Loss: 0.0285
# Epoch  29 Batch  459/1077 - Train Accuracy: 0.9702, Validation Accuracy: 0.9592, Loss: 0.0272
# Epoch  29 Batch  510/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9659, Loss: 0.0239
# Epoch  29 Batch  561/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9592, Loss: 0.0247
# Epoch  29 Batch  612/1077 - Train Accuracy: 0.9829, Validation Accuracy: 0.9624, Loss: 0.0220
# Epoch  29 Batch  663/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9549, Loss: 0.0227
# Epoch  29 Batch  714/1077 - Train Accuracy: 0.9862, Validation Accuracy: 0.9609, Loss: 0.0284
# Epoch  29 Batch  765/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9663, Loss: 0.0339
# Epoch  29 Batch  816/1077 - Train Accuracy: 0.9741, Validation Accuracy: 0.9609, Loss: 0.0269
# Epoch  29 Batch  867/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.9762, Loss: 0.0529
# Epoch  29 Batch  918/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9734, Loss: 0.0216
# Epoch  29 Batch  969/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9730, Loss: 0.0332
# Epoch  29 Batch 1020/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9734, Loss: 0.0222
# Epoch  29 Batch 1071/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9727, Loss: 0.0249
# Model Trained and Saved

# %%
# Print the loss and test/validation accuracies.

# Increase size of the subplots.
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 24 
fig_size[1] = 16
plt.rcParams["figure.figsize"] = fig_size

# ----- START ----- #
print("# Batches: {}".format(len(batches)))
loss_plot = plt.subplot(211)
loss_plot.set_title('Loss')
loss_plot.plot(batches, losses, 'g')
loss_plot.set_xlim([batches[0], batches[-1]])

acc_plot = plt.subplot(212)
acc_plot.set_title('Accuracy')
acc_plot.plot(batches, train_accs, 'r', label='Training Accuracy')
acc_plot.plot(batches, valid_accs, 'x', label='Validation Accuracy')
acc_plot.set_ylim([0, 1.0])
acc_plot.set_xlim([batches[0], batches[-1]])
acc_plot.legend(loc=4)

plt.tight_layout()
plt.show()
# ----- END ----- #
# Out:
# # Batches: 630

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    unk_id = vocab_to_int['<UNK>']
    return [vocab_to_int.get(w, unk_id) for w in sentence.lower().split(' ')]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old black truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [59, 29, 126, 35, 43, 94, 24]
#   English Words: ['he', 'saw', 'a', 'old', 'black', 'truck', '.']
#
# Prediction
#   Word Ids:      [117, 230, 331, 198, 340, 48, 68, 288, 1]
#   French Words: il a vu un vieux camion noir . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
